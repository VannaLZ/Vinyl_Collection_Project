# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../../Discogs_Exports/VannaBe_Collection_Price/Merged_Tableau/Merge_230703.csv")

# %%
df.tail()
# Out:
#           Artist                                              Title
# 119      Various  Vision Quest (Original Motion Picture Sound Tr...  \
# 120  Vasco Rossi                                         Albachiara
# 121          Yes                                      Big Generator
# 122          Yes                                  Going For The One
# 123          Yes                                            Relayer
#
#                     Collection   Min  Median  Higher  Min_230529
# 119  Original Collection Italy  1.95    5.11   25.55        1.95  \
# 120  Original Collection Italy  7.15   15.84   40.88        7.15
# 121           2023 Second Hand  2.45    7.34   12.68        2.45
# 122           2023 Second Hand  2.86    7.15   10.22        2.86
# 123           2023 Second Hand  5.05    9.05   15.16        5.05
#
#      Median_230529  Higher_230529  Min_230607  ...  Higher_230612  Min_230619
# 119           5.11          25.55        1.97  ...          25.55        1.91  \
# 120          15.84          40.88        7.23  ...          40.88        7.00
# 121           7.34          12.68        2.47  ...          12.68        2.39
# 122           7.15          10.22        2.89  ...          10.22        2.80
# 123           9.05          15.16        5.11  ...          15.16        4.95
#
#      Median_230619  Higher_230619  Min_230626  Median_230626  Higher_230626
# 119           5.00          25.00        1.93           5.05          25.27  \
# 120          15.50          40.00        7.08          15.67          40.44
# 121           7.18          12.40        2.42           7.26          12.54
# 122           7.00          10.00        2.83           7.08          10.11
# 123           8.85          14.84        5.00           8.95          15.00
#
#      Min_230703  Median_230703  Higher_230703
# 119        1.93           5.05          25.27
# 120        7.08          15.67          40.44
# 121        2.42           7.26          12.54
# 122        2.83           7.08          10.11
# 123        5.00           8.95          15.00
#
# [5 rows x 24 columns]

# %%
# Calculate sum of numeric columns
numeric_columns = df.select_dtypes(include=np.number).columns
sum_row = df[numeric_columns].sum().to_frame().T

# Add sum row to the DataFrame
df_with_sum = pd.concat([df, sum_row], ignore_index=True)

# Save the updated DataFrame in the DF variable.
df = df_with_sum

# %%
df = df.drop(index=2)

# %%
df.tail(2)
# Out:
#     Artist    Title        Collection     Min   Median   Higher  Min_230529
# 123    Yes  Relayer  2023 Second Hand    5.05     9.05    15.16        5.05  \
# 124    NaN      NaN               NaN  731.74  1504.93  3431.45      731.74
#
#      Median_230529  Higher_230529  Min_230607  ...  Higher_230612  Min_230619
# 123           9.05          15.16        5.11  ...          15.16        4.95  \
# 124        1504.93        3431.45      739.79  ...        3429.75      706.34
#
#      Median_230619  Higher_230619  Min_230626  Median_230626  Higher_230626
# 123           8.85          14.84        5.00           8.95          15.00  \
# 124        1473.41        3356.45      716.59        1496.43        3400.24
#
#      Min_230703  Median_230703  Higher_230703
# 123        5.00           8.95          15.00
# 124      716.14        1488.22        3373.18
#
# [2 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Artist', 'Title', 'Collection', 'Min', 'Median', 'Higher',
#        'Min_230529', 'Median_230529', 'Higher_230529', 'Min_230607',
#        'Median_230607', 'Higher_230607', 'Min_230612', 'Median_230612',
#        'Higher_230612', 'Min_230619', 'Median_230619', 'Higher_230619',
#        'Min_230626', 'Median_230626', 'Higher_230626', 'Min_230703',
#        'Median_230703', 'Higher_230703'],
#       dtype='object')

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
df.isnull().sum()
# Out:
# Artist           1
# Title            1
# Collection       1
# Min              0
# Median           0
# Higher           0
# Min_230529       0
# Median_230529    0
# Higher_230529    0
# Min_230607       0
# Median_230607    0
# Higher_230607    0
# Min_230612       0
# Median_230612    0
# Higher_230612    0
# Min_230619       0
# Median_230619    0
# Higher_230619    0
# Min_230626       0
# Median_230626    0
# Higher_230626    0
# Min_230703       0
# Median_230703    0
# Higher_230703    0
# dtype: int64

# %%
null_rows = df[df.isnull().any(axis=1)]
null_rows
# Out:
#     Artist Title Collection     Min   Median   Higher  Min_230529
# 124    NaN   NaN        NaN  731.74  1504.93  3431.45      731.74  \
#
#      Median_230529  Higher_230529  Min_230607  ...  Higher_230612  Min_230619
# 124        1504.93        3431.45      739.79  ...        3429.75      706.34  \
#
#      Median_230619  Higher_230619  Min_230626  Median_230626  Higher_230626
# 124        1473.41        3356.45      716.59        1496.43        3400.24  \
#
#      Min_230703  Median_230703  Higher_230703
# 124      716.14        1488.22        3373.18
#
# [1 rows x 24 columns]

# %%
df_filled = df.fillna("StringColumn")
df_filled.tail()
# Out:
#            Artist              Title                 Collection     Min
# 120   Vasco Rossi         Albachiara  Original Collection Italy    7.15  \
# 121           Yes      Big Generator           2023 Second Hand    2.45
# 122           Yes  Going For The One           2023 Second Hand    2.86
# 123           Yes            Relayer           2023 Second Hand    5.05
# 124  StringColumn       StringColumn               StringColumn  731.74
#
#       Median   Higher  Min_230529  Median_230529  Higher_230529  Min_230607
# 120    15.84    40.88        7.15          15.84          40.88        7.23  \
# 121     7.34    12.68        2.45           7.34          12.68        2.47
# 122     7.15    10.22        2.86           7.15          10.22        2.89
# 123     9.05    15.16        5.05           9.05          15.16        5.11
# 124  1504.93  3431.45      731.74        1504.93        3431.45      739.79
#
#      ...  Higher_230612  Min_230619  Median_230619  Higher_230619  Min_230626
# 120  ...          40.88        7.00          15.50          40.00        7.08  \
# 121  ...          12.68        2.39           7.18          12.40        2.42
# 122  ...          10.22        2.80           7.00          10.00        2.83
# 123  ...          15.16        4.95           8.85          14.84        5.00
# 124  ...        3429.75      706.34        1473.41        3356.45      716.59
#
#      Median_230626  Higher_230626  Min_230703  Median_230703  Higher_230703
# 120          15.67          40.44        7.08          15.67          40.44
# 121           7.26          12.54        2.42           7.26          12.54
# 122           7.08          10.11        2.83           7.08          10.11
# 123           8.95          15.00        5.00           8.95          15.00
# 124        1496.43        3400.24      716.14        1488.22        3373.18
#
# [5 rows x 24 columns]

# %%
df = df_filled

# %%
categories = df.select_dtypes(include = "object")
categories.head()
# Out:
#                      Artist
# 0                      a-ha  \
# 1                      a-ha
# 3                      a-ha
# 4  The Alan Parsons Project
# 5  The Alan Parsons Project
#
#                                                Title
# 0                   East Of The Sun West Of The Moon  \
# 1                               Hunting High And Low
# 3                                Stay On These Roads
# 4                                     Ammonia Avenue
# 5  Historias De Misterio E Imaginacion = Tales Of...
#
#                   Collection
# 0  Original Collection Italy
# 1  Original Collection Italy
# 3  Original Collection Italy
# 4           2023 Second Hand
# 5           2023 Second Hand

# %%
for col in categories.columns:
    print("------------------------------------------------------------", "\n")
    print(f"In the column '{col}', there are the following unique values that appear more than twice.")
    artist_counts = df[col].value_counts()
    filtered_counts = artist_counts[artist_counts > 2]
    result_df = pd.DataFrame(filtered_counts, columns=['count'])
    print(result_df.head(15))
    print("\n", "------------------------------------------------------------", "\n")
# Out:
# ------------------------------------------------------------
#
# In the column 'Artist', there are the following unique values that appear more than twice.
#                            count
# Artist
# Mike Oldfield                  7
# Various                        7
# Pink Floyd                     5
# Premiata Forneria Marconi      5
# Queen                          5
# Madonna                        4
# New Trolls                     4
# Spandau Ballet                 3
# The Alan Parsons Project       3
# The Doors                      3
# a-ha                           3
# Status Quo                     3
# Yes                            3
#
#  ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# In the column 'Title', there are the following unique values that appear more than twice.
# Empty DataFrame
# Columns: [count]
# Index: []
#
#  ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# In the column 'Collection', there are the following unique values that appear more than twice.
#                            count
# Collection
# Original Collection Italy     36
# 2023 Second Hand              23
# 2022 Second Hand              18
# Father Collection             17
# Original Collection           15
# 2021 Second Hand               7
# Original Collection Rita       3
# 45                             3
#
#  ------------------------------------------------------------

# %%
df.columns
# Out:
# Index(['Artist', 'Title', 'Collection', 'Min', 'Median', 'Higher',
#        'Min_230529', 'Median_230529', 'Higher_230529', 'Min_230607',
#        'Median_230607', 'Higher_230607', 'Min_230612', 'Median_230612',
#        'Higher_230612', 'Min_230619', 'Median_230619', 'Higher_230619',
#        'Min_230626', 'Median_230626', 'Higher_230626', 'Min_230703',
#        'Median_230703', 'Higher_230703'],
#       dtype='object')

# %%
column_order = ['Artist', 'Title', 'Collection', 'Min', 'Median', 'Higher',
       'Min_230529', 'Median_230529', 'Higher_230529', 'Min_230607',
       'Median_230607', 'Higher_230607', 'Min_230612', 'Median_230612',
       'Higher_230612', 'Min_230619', 'Median_230619', 'Higher_230619',
       'Min_230626', 'Median_230626', 'Higher_230626', 'Min_230703',
       'Median_230703', 'Higher_230703']
df = df[column_order]

# %%
df.columns
# Out:
# Index(['Artist', 'Title', 'Collection', 'Min', 'Median', 'Higher',
#        'Min_230529', 'Median_230529', 'Higher_230529', 'Min_230607',
#        'Median_230607', 'Higher_230607', 'Min_230612', 'Median_230612',
#        'Higher_230612', 'Min_230619', 'Median_230619', 'Higher_230619',
#        'Min_230626', 'Median_230626', 'Higher_230626', 'Min_230703',
#        'Median_230703', 'Higher_230703'],
#       dtype='object')

# %%
df.to_csv("../../../Discogs_Exports/VannaBe_Collection_Price/Merged_Tableau/Merge_230703.csv", index=False)

# %%
df = pd.read_csv("../../../Discogs_Exports/VannaBe_Collection_Price/Merged_Tableau/Merge_230703.csv")

# %%
df.tail()
# Out:
#            Artist              Title                 Collection     Min
# 119   Vasco Rossi         Albachiara  Original Collection Italy    7.15  \
# 120           Yes      Big Generator           2023 Second Hand    2.45
# 121           Yes  Going For The One           2023 Second Hand    2.86
# 122           Yes            Relayer           2023 Second Hand    5.05
# 123  StringColumn       StringColumn               StringColumn  731.74
#
#       Median   Higher  Min_230529  Median_230529  Higher_230529  Min_230607
# 119    15.84    40.88        7.15          15.84          40.88        7.23  \
# 120     7.34    12.68        2.45           7.34          12.68        2.47
# 121     7.15    10.22        2.86           7.15          10.22        2.89
# 122     9.05    15.16        5.05           9.05          15.16        5.11
# 123  1504.93  3431.45      731.74        1504.93        3431.45      739.79
#
#      ...  Higher_230612  Min_230619  Median_230619  Higher_230619  Min_230626
# 119  ...          40.88        7.00          15.50          40.00        7.08  \
# 120  ...          12.68        2.39           7.18          12.40        2.42
# 121  ...          10.22        2.80           7.00          10.00        2.83
# 122  ...          15.16        4.95           8.85          14.84        5.00
# 123  ...        3429.75      706.34        1473.41        3356.45      716.59
#
#      Median_230626  Higher_230626  Min_230703  Median_230703  Higher_230703
# 119          15.67          40.44        7.08          15.67          40.44
# 120           7.26          12.54        2.42           7.26          12.54
# 121           7.08          10.11        2.83           7.08          10.11
# 122           8.95          15.00        5.00           8.95          15.00
# 123        1496.43        3400.24      716.14        1488.22        3373.18
#
# [5 rows x 24 columns]

# %% [markdown]
# I  create three separate DataFrames (df_min, df_median, and df_higher) are created by indexing the original DataFrame (df) with the corresponding column lists.
#
# Each containing the columns with 'Min', 'Median', and 'Higher' respectively.

# %%
min_columns = [col for col in df.columns if 'Min' in col]
median_columns = [col for col in df.columns if 'Median' in col]
higher_columns = [col for col in df.columns if 'Higher' in col]

df_min = df[['Artist', 'Title', 'Collection'] + min_columns]
df_median = df[['Artist', 'Title', 'Collection'] + median_columns]
df_higher = df[['Artist', 'Title', 'Collection'] + higher_columns]

# %%
df_higher.head(2)
# Out:
#   Artist                             Title                 Collection  Higher
# 0   a-ha  East Of The Sun West Of The Moon  Original Collection Italy   26.28  \
# 1   a-ha              Hunting High And Low  Original Collection Italy   15.33
#
#    Higher_230529  Higher_230607  Higher_230612  Higher_230619  Higher_230626
# 0          26.28          26.57          26.28          25.72          26.29  \
# 1          15.33          15.49          15.33          15.00          15.16
#
#    Higher_230703
# 0          26.29
# 1          15.16

# %%
df_median.head(2)
# Out:
#   Artist                             Title                 Collection  Median
# 0   a-ha  East Of The Sun West Of The Moon  Original Collection Italy   11.62  \
# 1   a-ha              Hunting High And Low  Original Collection Italy   10.21
#
#    Median_230529  Median_230607  Median_230612  Median_230619  Median_230626
# 0          11.62          11.75          11.62          11.38          13.14  \
# 1          10.21          10.32          10.21          10.00          10.10
#
#    Median_230703
# 0          13.14
# 1          10.10

# %%
df_min.head(2)
# Out:
#   Artist                             Title                 Collection   Min
# 0   a-ha  East Of The Sun West Of The Moon  Original Collection Italy  5.05  \
# 1   a-ha              Hunting High And Low  Original Collection Italy  1.07
#
#    Min_230529  Min_230607  Min_230612  Min_230619  Min_230626  Min_230703
# 0        5.05        5.11        5.05        4.95        5.05        5.05
# 1        1.07        1.08        1.07        1.05        1.06        1.06

# %%
#check the 10 higher values taking in conosideration the last column which is the last entry.
df_min_sorted = df_min.sort_values("Min_230703", ascending=False)
df_min_sorted.head(10)
# Out:
#                            Artist                                 Title
# 123                  StringColumn                          StringColumn  \
# 74                     Pink Floyd             Delicate Sound Of Thunder
# 35                      Battiato*            L'Era Del Cinghiale Bianco
# 40               Graciela Guevara                      Graciela Guevara
# 89                          Queen                                 Queen
# 8                     The Beatles                              Hey Jude
# 78                   Pino Daniele                             Terra Mia
# 20   Dire Straits & Mark Knopfler  Private Investigations (The Best Of)
# 36                   Franco Cerri                                Nuages
# 42                   Jimi Hendrix                                 Blues
#
#                     Collection     Min  Min_230529  Min_230607  Min_230612
# 123               StringColumn  731.74      731.74      739.79      721.68  \
# 74         Original Collection   45.99       45.99       46.48       45.00
# 35           Father Collection   29.00       29.00       29.31       29.00
# 40   Original Collection Italy   21.57       21.57       21.80       21.57
# 89         Original Collection   21.14       21.14       21.36       21.14
# 8            Father Collection   20.44       20.44       20.66       20.44
# 78           Father Collection   20.44       20.44       20.66       20.44
# 20         Original Collection   19.44       19.44       19.65       19.03
# 36   Original Collection Italy   18.98       18.98       19.18       18.98
# 42         Original Collection   17.67       17.67       17.86       17.67
#
#      Min_230619  Min_230626  Min_230703
# 123      706.34      716.59      716.14
# 74        44.51       45.00       45.00
# 35        28.38       28.69       28.69
# 40        21.10       21.34       21.34
# 89        20.68       20.91       20.91
# 8         20.00       20.22       20.22
# 78        20.00       20.22       20.22
# 20        19.23       19.44       19.23
# 36        18.57       18.78       18.78
# 42        17.29       17.48       17.48

# %%
#check the 10 higher values taking in conosideration the last column which is the last entry.
df_median_sorted = df_median.sort_values("Median_230703", ascending=False)
df_median_sorted.head(10)
# Out:
#                            Artist                                 Title
# 123                  StringColumn                          StringColumn  \
# 35                      Battiato*            L'Era Del Cinghiale Bianco
# 74                     Pink Floyd             Delicate Sound Of Thunder
# 69                     New Trolls                                    UT
# 84      Premiata Forneria Marconi                          Per Un Amico
# 78                   Pino Daniele                             Terra Mia
# 82      Premiata Forneria Marconi                     L'Isola Di Niente
# 8                     The Beatles                              Hey Jude
# 20   Dire Straits & Mark Knopfler  Private Investigations (The Best Of)
# 77                     Pink Floyd                              The Wall
#
#               Collection   Median  Median_230529  Median_230607
# 123         StringColumn  1504.93        1504.93        1521.70  \
# 35     Father Collection    58.56          58.56          59.19
# 74   Original Collection    57.92          57.92          58.54
# 69     Father Collection    50.54          50.54          51.09
# 84     Father Collection    44.50          44.50          44.98
# 78     Father Collection    45.48          45.48          45.97
# 82     Father Collection    31.00          31.00          31.33
# 8      Father Collection    28.62          28.62          28.92
# 20   Original Collection    28.20          28.20          28.50
# 77     Father Collection    20.51          20.51          20.74
#
#      Median_230612  Median_230619  Median_230626  Median_230703
# 123        1502.23        1473.41        1496.43        1488.22
# 35           58.56          57.30          57.93          57.93
# 74           56.93          55.84          56.45          56.45
# 69           50.54          49.46          50.00          50.00
# 84           44.50          49.32          49.86          49.86
# 78           45.48          44.50          41.45          41.45
# 82           31.00          30.33          30.33          30.33
# 8            28.62          28.00          28.31          28.31
# 20           28.20          27.71          28.01          27.89
# 77           20.51          20.07          26.68          26.68

# %%
#check the 10 higher values taking in conosideration the last column which is the last entry.
df_higher_sorted = df_higher.sort_values("Higher_230703", ascending=False)
df_higher_sorted.head(10)
# Out:
#                                    Artist
# 123                          StringColumn  \
# 35                              Battiato*
# 84              Premiata Forneria Marconi
# 69                             New Trolls
# 74                             Pink Floyd
# 77                             Pink Floyd
# 82              Premiata Forneria Marconi
# 75                             Pink Floyd
# 78                           Pino Daniele
# 31   Emmylou Harris And The Nash Ramblers
#
#                                       Title           Collection   Higher
# 123                            StringColumn         StringColumn  3431.45  \
# 35               L'Era Del Cinghiale Bianco    Father Collection   180.00
# 84                             Per Un Amico    Father Collection   150.00
# 69                                       UT    Father Collection   126.36
# 74                Delicate Sound Of Thunder  Original Collection    90.96
# 77                                 The Wall    Father Collection    83.65
# 82                        L'Isola Di Niente    Father Collection    82.67
# 75          Soundtrack From The Film "More"    Father Collection    77.50
# 78                                Terra Mia    Father Collection    71.53
# 31   Ramble In Music City: The Lost Concert  Original Collection    69.75
#
#      Higher_230529  Higher_230607  Higher_230612  Higher_230619
# 123        3431.45        3465.35        3429.75        3356.45  \
# 35          180.00         181.94         180.00         176.13
# 84          150.00         151.61         150.00         146.77
# 69          126.36         127.72         126.36         123.64
# 74           90.96          91.93          89.00          88.03
# 77           83.65          84.55          83.65          81.85
# 82           82.67          83.56          82.67          80.89
# 75           77.50          78.33          77.50          75.83
# 78           71.53          72.30          71.53          69.99
# 31           69.75          70.50          69.75          68.25
#
#      Higher_230626  Higher_230703
# 123        3400.24        3373.18
# 35          178.06         178.06
# 84          148.39         148.39
# 69          125.00         125.00
# 74           89.00          89.00
# 77           82.75          82.75
# 82           80.88          80.88
# 75           76.67          76.67
# 78           70.76          70.76
# 31           69.00          69.00

# %%
df_higher.loc[:, 'Difference'] = df_higher.iloc[:, -2] - df_higher.iloc[:, 4]

# %%
df_higher.columns
# Out:
# Index(['Artist', 'Title', 'Collection', 'Higher', 'Higher_230529',
#        'Higher_230607', 'Higher_230612', 'Higher_230619', 'Higher_230626',
#        'Higher_230703', 'Difference'],
#       dtype='object')

# %%
df_higher_column_order = ['Artist', 'Title', 'Collection', 'Difference', 'Higher', 'Higher_230529',
       'Higher_230607', 'Higher_230612', 'Higher_230619', 'Higher_230626',
       'Higher_230703']
df_higher = df_higher[df_higher_column_order]

# %%
df_higher.head(1)
# Out:
#   Artist                             Title                 Collection
# 0   a-ha  East Of The Sun West Of The Moon  Original Collection Italy  \
#
#    Difference  Higher  Higher_230529  Higher_230607  Higher_230612
# 0        0.01   26.28          26.28          26.57          26.28  \
#
#    Higher_230619  Higher_230626  Higher_230703
# 0          25.72          26.29          26.29

# %%
positive_difference = df_higher[df_higher['Difference'] > 0]
positive_higher_difference = positive_difference.sort_values("Difference", ascending=False)

# %%
positive_higher_difference
# Out:
#                          Artist
# 54  Marvin Gaye & Tammi Terrell  \
# 22                    The Doors
# 34                Fleetwood Mac
# 9                Billie Holiday
# 67                   New Trolls
# 37                  Frank Zappa
# 52                      Madonna
# 19                 Dire Straits
# 48              Luca Barbarossa
# 80                   The Police
# 3      The Alan Parsons Project
# 92           Riccardo Cocciante
# 0                          a-ha
#
#                                                 Title
# 54                                             United  \
# 22  The Doors (Music From The Original Motion Pict...
# 34                                             Mirage
# 9                                       Lady In Satin
# 67                               Concerto Grosso N° 2
# 37                               Orchestral Favorites
# 52                                    The First Album
# 19                                      Making Movies
# 48                                  Al Di Là Del Muro
# 80                               Ghost In The Machine
# 3                                      Ammonia Avenue
# 92                               I Momenti Dell'Amore
# 0                    East Of The Sun West Of The Moon
#
#                    Collection  Difference  Higher  Higher_230529
# 54   Original Collection Rita        3.54   31.41          31.41  \
# 22  Original Collection Italy        3.39   36.17          36.17
# 34           2022 Second Hand        1.73   10.22          10.22
# 9         Original Collection        1.43   22.83          22.83
# 67          Father Collection        1.26   58.74          58.74
# 37  Original Collection Italy        0.89   13.95          13.95
# 52  Original Collection Italy        0.33   29.99          29.99
# 19           2023 Second Hand        0.24    5.66           5.66
# 48  Original Collection Italy        0.21    9.78           9.78
# 80           2021 Second Hand        0.16   14.84          14.84
# 3            2023 Second Hand        0.13   11.87          11.87
# 92  Original Collection Italy        0.04    3.96           3.96
# 0   Original Collection Italy        0.01   26.28          26.28
#
#     Higher_230607  Higher_230612  Higher_230619  Higher_230626  Higher_230703
# 54          31.75          31.41          30.74          34.95          34.95
# 22          36.56          39.99          39.13          39.56          39.56
# 34          10.33          12.08          11.82          11.95          11.95
# 9           24.79          24.52          24.00          24.26          24.26
# 67          59.37          58.74          57.47          58.11          60.00
# 37          15.16          15.00          14.68          14.84          14.84
# 52          30.31          29.99          29.35          29.67          30.32
# 19           5.72           5.66           5.84           5.90           5.90
# 48           9.88           9.78           9.57           9.67           9.99
# 80          15.16          15.00          14.68          15.00          15.00
# 3           12.00          11.87          11.62          11.74          12.00
# 92           4.00           4.00           3.91           4.00           4.00
# 0           26.57          26.28          25.72          26.29          26.29

# %%
df_median_copy = df_median.copy()
df_median_copy['Difference'] = df_median_copy.iloc[:, -2] - df_median_copy.iloc[:, 4]

# %%
df_median_copy.columns
# Out:
# Index(['Artist', 'Title', 'Collection', 'Median', 'Median_230529',
#        'Median_230607', 'Median_230612', 'Median_230619', 'Median_230626',
#        'Median_230703', 'Difference'],
#       dtype='object')

# %%
df_median_column_order = ['Artist', 'Title', 'Collection', 'Difference', 'Median', 'Median_230529',
       'Median_230607', 'Median_230612', 'Median_230619', 'Median_230626',
       'Median_230703']
df_median_copy = df_median_copy[df_median_column_order]

# %%
df_median_copy.head(1)
# Out:
#   Artist                             Title                 Collection
# 0   a-ha  East Of The Sun West Of The Moon  Original Collection Italy  \
#
#    Difference  Median  Median_230529  Median_230607  Median_230612
# 0        1.52   11.62          11.62          11.75          11.62  \
#
#    Median_230619  Median_230626  Median_230703
# 0          11.38          13.14          13.14

# %%
positive_difference = df_median_copy[df_median_copy['Difference'] > 0]
positive_median_difference = positive_difference.sort_values("Difference", ascending=False)

# %%
positive_median_difference
# Out:
#                           Artist
# 77                    Pink Floyd  \
# 84     Premiata Forneria Marconi
# 0                           a-ha
# 18                  Dire Straits
# 9                 Billie Holiday
# 3       The Alan Parsons Project
# 54   Marvin Gaye & Tammi Terrell
# 105               Spandau Ballet
# 26               Edoardo Bennato
# 37                   Frank Zappa
# 19                  Dire Straits
# 4       The Alan Parsons Project
# 52                       Madonna
# 80                    The Police
# 14              Claudio Baglioni
# 48               Luca Barbarossa
# 92            Riccardo Cocciante
#
#                                                  Title
# 77                                            The Wall  \
# 84                                        Per Un Amico
# 0                     East Of The Sun West Of The Moon
# 18                                          Communiqué
# 9                                        Lady In Satin
# 3                                       Ammonia Avenue
# 54                                              United
# 105                             Through The Barricades
# 26                         Non Farti Cadere Le Braccia
# 37                                Orchestral Favorites
# 19                                       Making Movies
# 4    Historias De Misterio E Imaginacion = Tales Of...
# 52                                     The First Album
# 80                                Ghost In The Machine
# 14                                    La Vita È Adesso
# 48                                   Al Di Là Del Muro
# 92                                I Momenti Dell'Amore
#
#                     Collection  Difference  Median  Median_230529
# 77           Father Collection        6.17   20.51          20.51  \
# 84           Father Collection        5.36   44.50          44.50
# 0    Original Collection Italy        1.52   11.62          11.62
# 18            2023 Second Hand        0.76    7.83           7.83
# 9          Original Collection        0.74   17.65          17.65
# 3             2023 Second Hand        0.62    6.38           6.38
# 54    Original Collection Rita        0.47   22.89          22.89
# 105           2022 Second Hand        0.30    4.14           4.14
# 26   Original Collection Italy        0.28    6.89           6.89
# 37   Original Collection Italy        0.25   11.62          11.62
# 19            2023 Second Hand        0.22    5.60           5.60
# 4             2023 Second Hand        0.18    5.62           5.62
# 52   Original Collection Italy        0.11   10.00          10.00
# 80            2021 Second Hand        0.08    7.91           7.91
# 14       2022 Second Hand Rita        0.05    5.17           5.17
# 48   Original Collection Italy        0.04    1.96           1.96
# 92   Original Collection Italy        0.02    1.98           1.98
#
#      Median_230607  Median_230612  Median_230619  Median_230626  Median_230703
# 77           20.74          20.51          20.07          26.68          26.68
# 84           44.98          44.50          49.32          49.86          49.86
# 0            11.75          11.62          11.38          13.14          13.14
# 18            7.83           7.75           7.58           8.59           8.59
# 9            18.79          18.59          18.19          18.39          18.39
# 3             6.45           6.38           6.24           6.31           7.00
# 54           23.14          22.89          22.40          23.36          23.36
# 105           4.36           4.31           4.39           4.44           4.44
# 26            6.97           7.25           7.09           7.17           7.17
# 37           12.13          12.00          11.74          11.87          11.87
# 19            5.66           5.60           5.76           5.82           5.82
# 4             5.68           5.62           5.50           5.80           5.80
# 52           10.11          10.00           9.78           9.89          10.11
# 80            8.08           7.99           7.82           7.99           7.99
# 14            5.22           5.17           5.16           5.22           5.22
# 48            1.98           1.96           1.92           1.94           2.00
# 92            2.00           2.00           1.96           2.00           2.00

# %%
df_min_copy = df_min.copy()
df_min_copy['Difference'] = df_min_copy.iloc[:, -2] - df_min_copy.iloc[:, 4]

# %%
df_min_copy.columns
# Out:
# Index(['Artist', 'Title', 'Collection', 'Min', 'Min_230529', 'Min_230607',
#        'Min_230612', 'Min_230619', 'Min_230626', 'Min_230703', 'Difference'],
#       dtype='object')

# %%
df_min_column_order = ['Artist', 'Title', 'Collection', 'Difference', 'Min', 'Min_230529', 'Min_230607',
       'Min_230612', 'Min_230619', 'Min_230626', 'Min_230703']
df_min_copy = df_min_copy[df_min_column_order]

# %%
df_min_copy.head(1)
# Out:
#   Artist                             Title                 Collection
# 0   a-ha  East Of The Sun West Of The Moon  Original Collection Italy  \
#
#    Difference   Min  Min_230529  Min_230607  Min_230612  Min_230619
# 0         0.0  5.05        5.05        5.11        5.05        4.95  \
#
#    Min_230626  Min_230703
# 0        5.05        5.05

# %%
positive_difference = df_min_copy[df_min_copy['Difference'] > 0]
positive_min_difference = positive_difference.sort_values("Difference", ascending=False)

# %%
positive_min_difference
# Out:
#                          Artist                        Title
# 82    Premiata Forneria Marconi            L'Isola Di Niente  \
# 26              Edoardo Bennato  Non Farti Cadere Le Braccia
# 13                     Cariocas                       Batida
# 37                  Frank Zappa         Orchestral Favorites
# 77                   Pink Floyd                     The Wall
# 19                 Dire Straits                Making Movies
# 12            Bruce Springsteen                Western Stars
# 80                   The Police         Ghost In The Machine
# 54  Marvin Gaye & Tammi Terrell                       United
# 92           Riccardo Cocciante         I Momenti Dell'Amore
#
#                    Collection  Difference    Min  Min_230529  Min_230607
# 82          Father Collection        1.95   8.16        8.16        8.25  \
# 26  Original Collection Italy        0.64   2.33        2.33        2.35
# 13  Original Collection Italy        0.31   6.13        6.13        6.58
# 37  Original Collection Italy        0.30   4.65        4.65        5.05
# 77          Father Collection        0.22  11.52       11.52       11.65
# 19           2023 Second Hand        0.21   4.79        4.79        4.85
# 12        Original Collection        0.07   4.10        4.10        4.14
# 80           2021 Second Hand        0.03   2.87        2.87        2.93
# 54   Original Collection Rita        0.02  12.95       12.95       13.09
# 92  Original Collection Italy        0.01   0.99        0.99        1.00
#
#     Min_230612  Min_230619  Min_230626  Min_230703
# 82        8.16        7.99       10.11       10.11
# 26        3.00        2.94        2.97        2.97
# 13        6.51        6.37        6.44        6.44
# 37        5.00        4.89        4.95        4.95
# 77       11.52       11.27       11.74       11.74
# 19        4.79        4.95        5.00        5.00
# 12        4.16        4.07        4.17        4.17
# 80        2.90        2.84        2.90        2.90
# 54       12.95       12.67       12.97       12.97
# 92        1.00        0.98        1.00        1.00
