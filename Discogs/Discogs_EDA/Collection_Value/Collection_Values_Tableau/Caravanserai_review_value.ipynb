# %%
import json
import pandas as pd

# %%
df = pd.read_csv("../../../Discogs_Exports/VannaBe_Collection_Price/Merged_Tableau/Merge_190623.csv")

# %%
df.head()
# Out:
#                      Artist                             Title   Min  Median
# 0                      a-ha  East Of The Sun West Of The Moon  5.05   11.62  \
# 1                      a-ha              Hunting High And Low  1.07   10.21
# 2                      a-ha                    Scoundrel Days  3.53    5.05
# 3                      a-ha               Stay On These Roads  3.00    7.00
# 4  The Alan Parsons Project                    Ammonia Avenue  1.12    6.38
#
#    Higher  Min_290523  Median_290523  Higher_290523  Min_070623
# 0   26.28        5.05          11.62          26.28        5.11  \
# 1   15.33        1.07          10.21          15.33        1.08
# 2   20.44        3.53           5.05          20.44        3.57
# 3   15.00        3.00           7.00          15.00        3.03
# 4   11.87        1.12           6.38          11.87        1.13
#
#    Median_070623  Higher_070623  Min_120623  Median_120623  Higher_120623
# ...

# %%
caravanserai = df.loc[df["Title"] == "Caravanserai"]

# %%
caravanserai.head()
# Out:
#       Artist         Title   Min  Median  Higher  Min_290523  Median_290523
# 97   Santana  Caravanserai  3.99    10.0   20.75        3.99           10.0  \
# 98   Santana  Caravanserai  3.99    10.0   20.75        3.99           10.0
# 99   Santana  Caravanserai  3.99    10.0   20.75        3.99           10.0
# 100  Santana  Caravanserai  3.99    10.0   20.75        3.99           10.0
# 101  Santana  Caravanserai  3.99    10.0   20.75        3.99           10.0
#
#      Higher_290523  Min_070623  Median_070623  Higher_070623  Min_120623
# 97           20.75        4.03          10.11          20.97        3.99  \
# 98           20.75        4.03          10.11          20.97        3.99
# 99           20.75        4.03          10.11          20.97        2.24
# 100          20.75        4.03          10.11          20.97        2.24
# 101          20.75        2.26           5.95          13.04        3.99
#
# ...

# %%
df_1 = pd.read_csv('../../../Discogs_Exports/VannaBe_Collection_Price/price_230523.csv')

# %%
df_1
# Out:
#                                              Unnamed: 0
# 0                                                   NaN  \
# 1               a-ha - East Of The Sun West Of The Moon
# 2                                             LP, Album
# 3                     Warner Bros. Records 7599 26314-1
# 4                                            1990 Italy
# ...                                                 ...
# 5927                      Other (Price on labels): 2-25
# 5928                         Other (Article): Арт. 11-1
# 5929  Other (Retail price on sleeve): Цена 2 руб. 50...
# 5930                          Edit Record Cleaning Date
# 5931                           Edit Record Cleaning Kit
#
#      Artist , Title, Label, Year, Format     Min  Median         Max
# 0                                    NaN     NaN     NaN         NaN  \
# 1                                    NaN     NaN     NaN         NaN
# 2                                    NaN     NaN     NaN         NaN
# ...

# %%
caravanserai_1 = df_1.loc[df_1["Unnamed: 0"] == "Santana - Caravanserai"]

# %%
caravanserai_1
# Out:
#                   Unnamed: 0 Artist , Title, Label, Year, Format  Min Median
# 4720  Santana - Caravanserai                                 NaN  NaN    NaN  \
# 4783  Santana - Caravanserai                                 NaN  NaN    NaN
#
#       Max Added  Folder  Rating  Album_Type  Style  ...  Group  Group_Members
# 4720  NaN   NaN     NaN     NaN         NaN    NaN  ...    NaN            NaN  \
# 4783  NaN   NaN     NaN     NaN         NaN    NaN  ...    NaN            NaN
#
#       Instrument(s)  Instrument(s)_2  Instrument(s)_3  Instrument(s)_4
# 4720            NaN              NaN              NaN              NaN  \
# 4783            NaN              NaN              NaN              NaN
#
#       Cover Art  Notes  Record Cleaning Date  Record Cleaning Kit
# 4720        NaN    NaN                   NaN                  NaN
# 4783        NaN    NaN                   NaN                  NaN
#
# [2 rows x 33 columns]

# %%
caravanserai_check = pd.concat([df_1.iloc[4720:4724], df_1.iloc[4783:4788]])

# %%
caravanserai_check
# Out:
#                   Unnamed: 0 Artist , Title, Label, Year, Format     Min
# 4720  Santana - Caravanserai                                 NaN     NaN  \
# 4721          LP, Album, Gat                                 NaN     NaN
# 4722           CBS S 69022 E                                 NaN     NaN
# 4723              1972 Spain                               €3.99  €10.00
# 4783  Santana - Caravanserai                                 NaN     NaN
# 4784       LP, Album, RE, RP                                 NaN     NaN
# 4785         CBS S CBS 32060                                 NaN     NaN
# 4786                  Europe                               €2.24   €5.88
# 4787    Edit Media Condition                                 NaN     NaN
#
#       Median          Max                      Added  Folder  Rating
# 4720     NaN          NaN                        NaN     NaN     NaN  \
# 4721     NaN          NaN                        NaN     NaN     NaN
# ...

# %% [markdown]
# With the addition of the "Added" column, this updated vinyl collection dataset offers improved insights into the presence of multiple copies for each vinyl.
#
# By addressing potential issues related to value verification, it enhances the accuracy and reliability of future analysis performed on the dataset.
