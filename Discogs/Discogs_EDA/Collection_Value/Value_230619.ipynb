# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>
#
# Follow the below instructions, and beware of the danger signs.

# %%
import pandas as pd
import re

# %%
pd.options.display.max_columns = None

# %%
# We should just copy the table in the following page https://www.discogs.com/user/VannaBe/collection?sort=max&sort_order=desc
# It is important to include all the columns and all the rows

price = pd.read_clipboard(sep="\t")

# %%
price
# Out:
#                                   Unnamed: 0
# 0                                        NaN  \
# 1     Battiato* - L'Era Del Cinghiale Bianco
# 2                                  LP, Album
# 3                           EMI 3C 064-18285
# 4                                 1979 Italy
# ...                                      ...
# 5914                                     NaN
# 5915                      Cover - Bruce Meek
# 5916                              Edit Notes
# 5917               Edit Record Cleaning Date
# 5918                Edit Record Cleaning Kit
#
#      Artist, Title, Label, Year, Format     Min   Median               Max
# 0                                   NaN     NaN      NaN                NaN  \
# 1                                   NaN     NaN      NaN                NaN
# 2                                   NaN     NaN      NaN                NaN
# 3                                   NaN     NaN      NaN                NaN
# 4                                €28.38  €57.30  €176.13  about 1 month ago
# ...                                 ...     ...      ...                ...
# 5914                                NaN     NaN      NaN                NaN
# 5915                                NaN     NaN      NaN                NaN
# 5916                                NaN     NaN      NaN                NaN
# 5917                                NaN     NaN      NaN                NaN
# 5918                                NaN     NaN      NaN                NaN
#
#                   Added  Folder  Rating  Album_Type  Style  Genre  Recorded
# 0                   NaN     NaN     NaN         NaN    NaN    NaN       NaN  \
# 1                   NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 2                   NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 3                   NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 4     Father Collection     NaN     NaN         NaN    NaN    NaN       NaN
# ...                 ...     ...     ...         ...    ...    ...       ...
# 5914                NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 5915                NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 5916                NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 5917                NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 5918                NaN     NaN     NaN         NaN    NaN    NaN       NaN
#
#       Original Released  Artist_City  Artist_Country  Artist_Region_State
# 0                   NaN          NaN             NaN                  NaN  \
# 1                   NaN          NaN             NaN                  NaN
# 2                   NaN          NaN             NaN                  NaN
# 3                   NaN          NaN             NaN                  NaN
# 4                   NaN          NaN             NaN                  NaN
# ...                 ...          ...             ...                  ...
# 5914                NaN          NaN             NaN                  NaN
# 5915                NaN          NaN             NaN                  NaN
# 5916                NaN          NaN             NaN                  NaN
# 5917                NaN          NaN             NaN                  NaN
# 5918                NaN          NaN             NaN                  NaN
#
#       Purchased  Year_Purchased  Shop  Shop_City  Shop_Region_State
# 0           NaN             NaN   NaN        NaN                NaN  \
# 1           NaN             NaN   NaN        NaN                NaN
# 2           NaN             NaN   NaN        NaN                NaN
# 3           NaN             NaN   NaN        NaN                NaN
# 4           NaN             NaN   NaN        NaN                NaN
# ...         ...             ...   ...        ...                ...
# 5914        NaN             NaN   NaN        NaN                NaN
# 5915        NaN             NaN   NaN        NaN                NaN
# 5916        NaN             NaN   NaN        NaN                NaN
# 5917        NaN             NaN   NaN        NaN                NaN
# 5918        NaN             NaN   NaN        NaN                NaN
#
#       Shop_Country  Years active  Group  Group_Members  Instrument(s)
# 0              NaN           NaN    NaN            NaN            NaN  \
# 1              NaN           NaN    NaN            NaN            NaN
# 2              NaN           NaN    NaN            NaN            NaN
# 3              NaN           NaN    NaN            NaN            NaN
# 4              NaN           NaN    NaN            NaN            NaN
# ...            ...           ...    ...            ...            ...
# 5914           NaN           NaN    NaN            NaN            NaN
# 5915           NaN           NaN    NaN            NaN            NaN
# 5916           NaN           NaN    NaN            NaN            NaN
# 5917           NaN           NaN    NaN            NaN            NaN
# 5918           NaN           NaN    NaN            NaN            NaN
#
#       Instrument(s)_2  Instrument(s)_3  Instrument(s)_4  Cover Art  Notes
# 0                 NaN              NaN              NaN        NaN    NaN  \
# 1                 NaN              NaN              NaN        NaN    NaN
# 2                 NaN              NaN              NaN        NaN    NaN
# 3                 NaN              NaN              NaN        NaN    NaN
# 4                 NaN              NaN              NaN        NaN    NaN
# ...               ...              ...              ...        ...    ...
# 5914              NaN              NaN              NaN        NaN    NaN
# 5915              NaN              NaN              NaN        NaN    NaN
# 5916              NaN              NaN              NaN        NaN    NaN
# 5917              NaN              NaN              NaN        NaN    NaN
# 5918              NaN              NaN              NaN        NaN    NaN
#
#       Record Cleaning Date  Record Cleaning Kit
# 0                      NaN                  NaN
# 1                      NaN                  NaN
# 2                      NaN                  NaN
# 3                      NaN                  NaN
# 4                      NaN                  NaN
# ...                    ...                  ...
# 5914                   NaN                  NaN
# 5915                   NaN                  NaN
# 5916                   NaN                  NaN
# 5917                   NaN                  NaN
# 5918                   NaN                  NaN
#
# [5919 rows x 33 columns]

# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>
#
# Change the name of the file with the today date.

# %%
price.to_json('../../Discogs_Exports/VannaBe_Collection_Price/price_190623.json', orient='columns', indent=None)

# %%
df_price_190623 = pd.read_json('../../Discogs_Exports/VannaBe_Collection_Price/price_190623.json')

# %%
df = df_price_190623.iloc[:, :6]

# %%
search_phrase = "Dimo Safari"
result = df[df["Unnamed: 0"].str.contains(search_phrase, na=False)]

# %%
result
# Out:
#                                  Unnamed: 0
# 175  Photography By [Package] – Dimo Safari  \
#
#     Artist, Title, Label, Year, Format   Min Median  Max  Added
# 175                               None  None   None  None  None

# %%
rows_160_to_181 = df.iloc[160:181]
rows_160_to_181
# Out:
#                                             Unnamed: 0
# 160  Backing Vocals – Durga McBroom, Margret Taylor...  \
# 161                           Bass, Vocals – Guy Pratt
# 162                       Guitar, Vocals – Tim Renwick
# 163                      Keyboards, Vocals – Jon Carin
# 164                           Percussion – Gary Wallis
# 165                     Saxophone, Guitar – Scott Page
# 166            Engineer [Assisted By] – Robert Hrycyna
# 167                 Engineer [Recording] – Dave Hewitt
# 168                 Mastered By [Audio] – Andy Jackson
# 169                Mastered By [Vinyl] – Stuart Hawkes
# 170          Mixed By [Audio Transfers] – Damon Iddins
# 171      Recorded By – Remote Recording Services, Inc.
# 172                               Remix – Andy Jackson
# 173  Design [Front Cover Design Inspired By] – Aubr...
# 174    Design, Artwork – Blade Design Ltd., Steve Knee
# 175             Photography By [Package] – Dimo Safari
# 176  Photography By [Sleeve] – Rupert Truman, Storm...
# 177               Die cut box cover with hype sticker:
# 178  LIVE 3-LP\nPINK FLOYD\nDelicate Sound of Thund...
# 179                 Children of Islington Green School
# 180  Backing Vocals – Bruce Johnston, Islington Gre...
#
#     Artist, Title, Label, Year, Format   Min Median  Max  Added
# 160                               None  None   None  None  None
# 161                               None  None   None  None  None
# 162                               None  None   None  None  None
# 163                               None  None   None  None  None
# 164                               None  None   None  None  None
# 165                               None  None   None  None  None
# 166                               None  None   None  None  None
# 167                               None  None   None  None  None
# 168                               None  None   None  None  None
# 169                               None  None   None  None  None
# 170                               None  None   None  None  None
# 171                               None  None   None  None  None
# 172                               None  None   None  None  None
# 173                               None  None   None  None  None
# 174                               None  None   None  None  None
# 175                               None  None   None  None  None
# 176                               None  None   None  None  None
# 177                               None  None   None  None  None
# 178                               None  None   None  None  None
# 179                               None  None   None  None  None
# 180                               None  None   None  None  None

# %%
# Find the rows that contain the Euro symbol
euro_rows = df[df.apply(lambda row: row.astype(str).str.contains('€').any(), axis=1)].index

# %%
euro_rows
# Out:
# Index([   4,   42,   90,  131,  178,  190,  232,  279,  316,  356,
#        ...
#        5120, 5177, 5221, 5257, 5290, 5333, 5381, 5413, 5445, 5484],
#       dtype='int64', length=133)

# %%
cell_value = df.at[178, 'Unnamed: 0']
print(cell_value)
# Out:
# LIVE 3-LP
# PINK FLOYD
# Delicate Sound of Thunder
# Remixed from the original master tapes
# Heavyweight 180g Vinyl
# 24-page Booklet
# 23 songs
# Approx. 2 1/2 hours
# Features 9 songs
# not included on the
# 1988 2-LP.
#
# Edit Record Cleaning Date
# Edit Record Cleaning Kit
#
# Pink Floyd - The Wall
# 2xLP, Album
# Columbia, Columbia PC2 36183, 36183
# 1979 Canada	€11.27	€20.07	€81.85	about 1 month ago	Father Collection
# Good Plus (G+)
#
# Very Good (VG)
#
# Tribute Album
#
# Prog Rock
#
# Rock
#
# Britannia Row
# London, England, UK
# Super Bear
# Nice, France
# Miraval (Correns)
# 30th Street
# New York, New York, USA
# Producers Workshop
# Los Angeles
# Cherokee
# Hollywood)
#
# 1979
#
# London
#
# UK
#
# England
#
# In-Store
#
# Unknown
#
# Unknown
#
# Unknown
#
# Unknown
#
# Italy
#
# 1965–1994
# 2005
# 2007
# 2013–2014
# 2022
#
# Yes
#
# Roger Waters
# David Gilmour
# Nick Mason
# Richard Wright
#
# Roger Waters – vocals, bass guitar, synthesizer, acoustic guitar, electric guitar
# David Gilmour – vocals, electric,and acoustic guitars, bass guitar,ARP Quadra synthesizers
#
# Nick Mason – drums and percussion
# Richard Wright – piano, Hammond organ, Prophet-5, ARP Quadra, Minimoog synthesizers, Fender Rhodes, Wurlitzer electric pianos, clavinet.
#
# Bob Ezrin - piano, Hammond organ and harmonium, Prophet-5
# Jeff Porcaro - drums
# Lee Ritenour – rhythm guitar, acoustic guitar
# Fred Mandel – Hammond organ
# Bobbye Hall – congas and bongos
# Frank Marocco – concertina
# Larry Williams – clarinet
#
# New York Orchestra & Opera
# Harry Waters – child's voice on Goodbye Blue Sky"

# %%
# Create a list of rows to keep, including the three rows before each Euro row
rows_to_keep = []
for row in euro_rows:
    rows_to_keep.extend(range(row - 3, row + 1))

# %%
# Keep only the selected rows
df = df.loc[rows_to_keep]

# %%
df = df.reset_index(drop=True)

# %%
# Define the row indices to drop
rows_to_drop = []
for i in range(1, len(df), 4):
    rows_to_drop.extend([i, i+1])

# Drop the rows from the DataFrame
df = df.drop(rows_to_drop)

# Reset the index of the DataFrame
df = df.reset_index(drop=True)

# %%
# Iterate over the rows in the DataFrame
for i in range(1, len(df)):
    # Check if the row index is odd
    if i % 2 == 1:
        # Copy the value from the previous row's first column and paste it into the current row's first column
        df.iloc[i, 0] = df.iloc[i-1, 0]

# %%
# Iterate over the rows in the DataFrame
for i in range(1, len(df)):
    # Check if the row index is odd
    if i % 2 == 1:
        # Copy the value from the previous row's first column and paste it into the current row's first column
        df.iloc[i, 0] = df.iloc[i-1, 0]

# Delete rows with even indices
df = df.drop(df.index[::2])

# Reset the index of the DataFrame
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#                                  Unnamed: 0
# 0    Battiato* - L'Era Del Cinghiale Bianco  \
# 1  Premiata Forneria Marconi - Per Un Amico
# 2                           New Trolls - UT
# 3    Pink Floyd - Delicate Sound Of Thunder
# 4    Photography By [Package] – Dimo Safari
#
#   Artist, Title, Label, Year, Format     Min   Median               Max
# 0                             €28.38  €57.30  €176.13  about 1 month ago  \
# 1                             €14.68  €49.32  €146.77  about 1 month ago
# 2                             €12.98  €49.46  €123.64  about 1 month ago
# 3                             €44.51  €55.84   €88.03  about 1 month ago
# 4                               None    None     None               None
#
#                  Added
# 0    Father Collection
# 1    Father Collection
# 2    Father Collection
# 3  Original Collection
# 4                 None

# %%
df
# Out:
#                                             Unnamed: 0
# 0               Battiato* - L'Era Del Cinghiale Bianco  \
# 1             Premiata Forneria Marconi - Per Un Amico
# 2                                      New Trolls - UT
# 3               Pink Floyd - Delicate Sound Of Thunder
# 4               Photography By [Package] – Dimo Safari
# ..                                                 ...
# 128            Culture Club - From Luxury To Heartache
# 129  Fernandez Pray Und Sein Orchester - Midnight I...
# 130          Riccardo Cocciante - I Momenti Dell'Amore
# 131                    Mungo Jerry - In The Summertime
# 132   Santo & Johnny - Il Padrino Famosi Temi Da Films
#
#     Artist, Title, Label, Year, Format     Min   Median               Max
# 0                               €28.38  €57.30  €176.13  about 1 month ago  \
# 1                               €14.68  €49.32  €146.77  about 1 month ago
# 2                               €12.98  €49.46  €123.64  about 1 month ago
# 3                               €44.51  €55.84   €88.03  about 1 month ago
# 4                                 None    None     None               None
# ..                                 ...     ...      ...                ...
# 128                              €0.99   €2.30    €5.69  about 1 month ago
# 129                              €1.88   €4.69    €5.62  about 1 month ago
# 130                              €0.98   €1.96    €3.91        26 days ago
# 131                              €0.49   €1.71    €3.91  about 1 month ago
# 132                              €2.74   €3.02    €3.29        26 days ago
#
#                          Added
# 0            Father Collection
# 1            Father Collection
# 2            Father Collection
# 3          Original Collection
# 4                         None
# ..                         ...
# 128           2022 Second Hand
# 129                         45
# 130  Original Collection Italy
# 131                         45
# 132  Original Collection Italy
#
# [133 rows x 6 columns]

# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>
#
# Change the name of the file with the today date.

# %%
# Inserts a new column named 'Artist'at index 0 and 'Title' at index 1 in the DataFrame df. 
# The initial values in these columns are set as empty strings ('').
df.insert(0, 'Artist', '')
df.insert(1, 'Title', '')

# %%
df.columns
# Out:
# Index(['Artist', 'Title', 'Unnamed: 0', 'Artist, Title, Label, Year, Format',
#        'Min', 'Median', 'Max ', 'Added'],
#       dtype='object')

# %%
# Split the values in the 'Unnamed: 0' column using the delimiter ' - '
# The str.split() function returns a DataFrame with two columns ('Artist' and 'Title')
# containing the split values.
# By assigning this DataFrame to df[['Artist', 'Title']],
# the values are placed in the respective columns.
# The parameter n=1 indicates that the splitting should be done only once,
# resulting in a maximum of two parts.
# The expand=True parameter ensures that the result is returned as a DataFrame with two columns.
df[['Artist', 'Title']] = df['Unnamed: 0'].str.split(' - ', n=1, expand=True)

# Drops the 'Artist, Title, Label, Year, Format' column from the DataFrame df along the specified axis
# (axis=1 indicates the column axis).
# The inplace=True parameter ensures that the DataFrame is modified in place,
# without creating a new copy.
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                    Artist                       Title
# 0                               Battiato*  L'Era Del Cinghiale Bianco  \
# 1               Premiata Forneria Marconi                Per Un Amico
# 2                              New Trolls                          UT
# 3                              Pink Floyd   Delicate Sound Of Thunder
# 4  Photography By [Package] – Dimo Safari                        None
#
#   Artist, Title, Label, Year, Format     Min   Median               Max
# 0                             €28.38  €57.30  €176.13  about 1 month ago  \
# 1                             €14.68  €49.32  €146.77  about 1 month ago
# 2                             €12.98  €49.46  €123.64  about 1 month ago
# 3                             €44.51  €55.84   €88.03  about 1 month ago
# 4                               None    None     None               None
#
#                  Added
# 0    Father Collection
# 1    Father Collection
# 2    Father Collection
# 3  Original Collection
# 4                 None

# %%
filtered_data = df[df['Artist'] == 'Pink Floyd']
print(filtered_data)
# Out:
#         Artist                            Title
# 3   Pink Floyd        Delicate Sound Of Thunder  \
# 6   Pink Floyd  Soundtrack From The Film "More"
# 11  Pink Floyd        The Dark Side Of The Moon
# 17  Pink Floyd                          Animals
# 63  Pink Floyd                  Masters Of Rock
#
#    Artist, Title, Label, Year, Format     Min  Median               Max
# 3                              €44.51  €55.84  €88.03  about 1 month ago  \
# 6                               €7.58  €18.96  €75.83  about 1 month ago
# 11                              €9.30  €24.45  €52.84  about 1 month ago
# 17                              €6.78  €20.33  €43.56  about 1 month ago
# 63                              €4.88  €10.74  €19.57  about 1 month ago
#
#                   Added
# 3   Original Collection
# 6     Father Collection
# 11    Father Collection
# 17    Father Collection
# 63    Father Collection

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Artist                              133 non-null    object
#  1   Title                               132 non-null    object
#  2   Artist, Title, Label, Year, Format  132 non-null    object
#  3   Min                                 132 non-null    object
#  4   Median                              132 non-null    object
# dtypes: object(5)
# memory usage: 5.3+ KB

# %%
df["Artist, Title, Label, Year, Format"] = df["Artist, Title, Label, Year, Format"].str.replace("€", "").astype(float).round(2)

# %%
df["Min"] = df["Min"].str.replace("€", "").astype(float).round(2)

# %%
df["Median"] = df["Median"].str.replace("€", "").astype(float).round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Artist                              133 non-null    object
#  1   Title                               132 non-null    object
#  2   Artist, Title, Label, Year, Format  132 non-null    float64
#  3   Min                                 132 non-null    float64
#  4   Median                              132 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 5.3+ KB

# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>
#
# Change the name of the file with the today date.

# %%
df = df.rename(columns={'Artist, Title, Label, Year, Format':"Min_190623", 'Min': 'Median_190623', 'Median': 'Higher_190623'})

# %%
df.loc["Pink Floyd"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/66/3gn2x5sj3tlfxjp4wp1zg9n00000gn/T/ipykernel_26565/3696466139.py in <module>
# ----> 1 df.loc["Pink Floyd"]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1101
#    1102             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103             return self._getitem_axis(maybe_callable, axis=axis)
#    1104
#    1105     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1341         # fall thru to straight lookup
#    1342         self._validate_key(key, axis)
# -> 1343         return self._get_label(key, axis=axis)
#    1344
#    1345     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1291     def _get_label(self, label, axis: AxisInt):
#    1292         # GH#5567 this will fail if the label is not present in the axis.
# -> 1293         return self.obj.xs(label, axis=axis)
#    1294
#    1295     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4093                     new_index = index[loc]
#    4094         else:
# -> 4095             loc = index.get_loc(key)
#    4096
#    4097             if isinstance(loc, np.ndarray):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     347                 raise KeyError(key) from err
#     348         self._check_indexing_error(key)
# --> 349         raise KeyError(key)
#     350
#     351     def _get_indexer(
#
# KeyError: 'Pink Floyd'

# %%
df.to_json("../../Discogs_Exports/VannaBe_Collection_Price/Final_190623.json", orient='columns', indent=None)
