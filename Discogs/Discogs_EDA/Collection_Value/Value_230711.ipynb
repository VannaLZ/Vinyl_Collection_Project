# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>
#
# Follow the below instructions, and beware of the danger signs.

# %%
import pandas as pd
import re

# %%
pd.options.display.max_columns = None

# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>

# %% [markdown]
# Sort by Max

# %%
# We should just copy the table in the following page https://www.discogs.com/user/VannaBe/collection?sort=max&sort_order=desc
# It is important to include all the columns and all the rows

price = pd.read_clipboard(sep="\t")

# %%
price
# Out:
#                                   Unnamed: 0
# 0                                        NaN  \
# 1     Battiato* - L'Era Del Cinghiale Bianco
# 2                                  LP, Album
# 3                           EMI 3C 064-18285
# 4                                 1979 Italy
# ...                                      ...
# 5918                                     NaN
# 5919                      Cover - Bruce Meek
# 5920                              Edit Notes
# 5921               Edit Record Cleaning Date
# 5922                Edit Record Cleaning Kit
#
#      Artist, Title, Label, Year, Format     Min   Median          Max
# 0                                   NaN     NaN      NaN           NaN  \
# 1                                   NaN     NaN      NaN           NaN
# 2                                   NaN     NaN      NaN           NaN
# 3                                   NaN     NaN      NaN           NaN
# 4                                €21.76  €58.34  €178.04  3 months ago
# ...                                 ...     ...      ...           ...
# 5918                                NaN     NaN      NaN           NaN
# 5919                                NaN     NaN      NaN           NaN
# 5920                                NaN     NaN      NaN           NaN
# 5921                                NaN     NaN      NaN           NaN
# 5922                                NaN     NaN      NaN           NaN
#
#                   Added  Folder  Rating  Album_Type  Style  Genre  Recorded
# 0                   NaN     NaN     NaN         NaN    NaN    NaN       NaN  \
# 1                   NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 2                   NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 3                   NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 4     Father Collection     NaN     NaN         NaN    NaN    NaN       NaN
# ...                 ...     ...     ...         ...    ...    ...       ...
# 5918                NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 5919                NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 5920                NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 5921                NaN     NaN     NaN         NaN    NaN    NaN       NaN
# 5922                NaN     NaN     NaN         NaN    NaN    NaN       NaN
#
#       Original Released  Artist_City  Artist_Country  Artist_Region_State
# 0                   NaN          NaN             NaN                  NaN  \
# 1                   NaN          NaN             NaN                  NaN
# 2                   NaN          NaN             NaN                  NaN
# 3                   NaN          NaN             NaN                  NaN
# 4                   NaN          NaN             NaN                  NaN
# ...                 ...          ...             ...                  ...
# 5918                NaN          NaN             NaN                  NaN
# 5919                NaN          NaN             NaN                  NaN
# 5920                NaN          NaN             NaN                  NaN
# 5921                NaN          NaN             NaN                  NaN
# 5922                NaN          NaN             NaN                  NaN
#
#       Purchased  Year_Purchased  Shop  Shop_City  Shop_Region_State
# 0           NaN             NaN   NaN        NaN                NaN  \
# 1           NaN             NaN   NaN        NaN                NaN
# 2           NaN             NaN   NaN        NaN                NaN
# 3           NaN             NaN   NaN        NaN                NaN
# 4           NaN             NaN   NaN        NaN                NaN
# ...         ...             ...   ...        ...                ...
# 5918        NaN             NaN   NaN        NaN                NaN
# 5919        NaN             NaN   NaN        NaN                NaN
# 5920        NaN             NaN   NaN        NaN                NaN
# 5921        NaN             NaN   NaN        NaN                NaN
# 5922        NaN             NaN   NaN        NaN                NaN
#
#       Shop_Country  Years active  Group  Group_Members  Instrument(s)
# 0              NaN           NaN    NaN            NaN            NaN  \
# 1              NaN           NaN    NaN            NaN            NaN
# 2              NaN           NaN    NaN            NaN            NaN
# 3              NaN           NaN    NaN            NaN            NaN
# 4              NaN           NaN    NaN            NaN            NaN
# ...            ...           ...    ...            ...            ...
# 5918           NaN           NaN    NaN            NaN            NaN
# 5919           NaN           NaN    NaN            NaN            NaN
# 5920           NaN           NaN    NaN            NaN            NaN
# 5921           NaN           NaN    NaN            NaN            NaN
# 5922           NaN           NaN    NaN            NaN            NaN
#
#       Instrument(s)_2  Instrument(s)_3  Instrument(s)_4  Cover Art  Notes
# 0                 NaN              NaN              NaN        NaN    NaN  \
# 1                 NaN              NaN              NaN        NaN    NaN
# 2                 NaN              NaN              NaN        NaN    NaN
# 3                 NaN              NaN              NaN        NaN    NaN
# 4                 NaN              NaN              NaN        NaN    NaN
# ...               ...              ...              ...        ...    ...
# 5918              NaN              NaN              NaN        NaN    NaN
# 5919              NaN              NaN              NaN        NaN    NaN
# 5920              NaN              NaN              NaN        NaN    NaN
# 5921              NaN              NaN              NaN        NaN    NaN
# 5922              NaN              NaN              NaN        NaN    NaN
#
#       Record Cleaning Date  Record Cleaning Kit
# 0                      NaN                  NaN
# 1                      NaN                  NaN
# 2                      NaN                  NaN
# 3                      NaN                  NaN
# 4                      NaN                  NaN
# ...                    ...                  ...
# 5918                   NaN                  NaN
# 5919                   NaN                  NaN
# 5920                   NaN                  NaN
# 5921                   NaN                  NaN
# 5922                   NaN                  NaN
#
# [5923 rows x 33 columns]

# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>
#
# Change the name of the file with the today date.

# %%
price.to_json('../../Discogs_Exports/VannaBe_Collection_Price/price_110723.json', orient='columns', indent=None)

# %%
df_price= pd.read_json('../../Discogs_Exports/VannaBe_Collection_Price/price_110723.json')

# %%
df = df_price.iloc[:, :6]

# %%
df
# Out:
#                                   Unnamed: 0
# 0                                       None  \
# 1     Battiato* - L'Era Del Cinghiale Bianco
# 2                                  LP, Album
# 3                           EMI 3C 064-18285
# 4                                 1979 Italy
# ...                                      ...
# 5918                                    None
# 5919                      Cover - Bruce Meek
# 5920                              Edit Notes
# 5921               Edit Record Cleaning Date
# 5922                Edit Record Cleaning Kit
#
#      Artist, Title, Label, Year, Format     Min   Median          Max
# 0                                  None    None     None          None  \
# 1                                  None    None     None          None
# 2                                  None    None     None          None
# 3                                  None    None     None          None
# 4                                €21.76  €58.34  €178.04  3 months ago
# ...                                 ...     ...      ...           ...
# 5918                               None    None     None          None
# 5919                               None    None     None          None
# 5920                               None    None     None          None
# 5921                               None    None     None          None
# 5922                               None    None     None          None
#
#                   Added
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4     Father Collection
# ...                 ...
# 5918               None
# 5919               None
# 5920               None
# 5921               None
# 5922               None
#
# [5923 rows x 6 columns]

# %%
# Find the rows that contain the Euro symbol
euro_rows = df[df.apply(lambda row: row.astype(str).str.contains('€').any(), axis=1)].index

# %%
euro_rows
# Out:
# Index([   4,   42,   90,  131,  178,  190,  232,  279,  319,  356,
#        ...
#        5124, 5181, 5225, 5261, 5294, 5337, 5385, 5417, 5449, 5488],
#       dtype='int64', length=133)

# %%
# Create a list of rows to keep, including the three rows before each Euro row
rows_to_keep = []
for row in euro_rows:
    rows_to_keep.extend(range(row - 3, row + 1))

# %%
# Keep only the selected rows
df = df.loc[rows_to_keep]

# %%
df = df.reset_index(drop=True)

# %%
# Define the row indices to drop
rows_to_drop = []
for i in range(1, len(df), 4):
    rows_to_drop.extend([i, i+1])

# Drop the rows from the DataFrame
df = df.drop(rows_to_drop)

# Reset the index of the DataFrame
df = df.reset_index(drop=True)

# %%
# Iterate over the rows in the DataFrame
for i in range(1, len(df)):
    # Check if the row index is odd
    if i % 2 == 1:
        # Copy the value from the previous row's first column and paste it into the current row's first column
        df.iloc[i, 0] = df.iloc[i-1, 0]

# %%
# Iterate over the rows in the DataFrame
for i in range(1, len(df)):
    # Check if the row index is odd
    if i % 2 == 1:
        # Copy the value from the previous row's first column and paste it into the current row's first column
        df.iloc[i, 0] = df.iloc[i-1, 0]

# Delete rows with even indices
df = df.drop(df.index[::2])

# Reset the index of the DataFrame
df = df.reset_index(drop=True)

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                                             Unnamed: 0
# 0               Battiato* - L'Era Del Cinghiale Bianco  \
# 1             Premiata Forneria Marconi - Per Un Amico
# 2                                      New Trolls - UT
# 3               Pink Floyd - Delicate Sound Of Thunder
# 4        Premiata Forneria Marconi - L'Isola Di Niente
# 5         Pink Floyd - Soundtrack From The Film "More"
# 6    Emmylou Harris And The Nash Ramblers - Ramble ...
# 7                             Pino Daniele - Terra Mia
# 8                   Bruce Springsteen - Tunnel Of Love
# 9                    New Trolls - Concerto Grosso N° 2
# 10              Pink Floyd - The Dark Side Of The Moon
# 11                               Franco Cerri - Nuages
# 12                          Andrew Lloyd Webber - Cats
# 13                    Mike Oldfield - Tubular Bells II
# 14        Premiata Forneria Marconi - Photos Of Ghosts
# 15                                Pink Floyd - Animals
# 16                                    Queen - The Game
# 17                   Bruce Springsteen - Western Stars
# 18                            Vasco Rossi - Albachiara
# 19                              Mike Oldfield - Amarok
# 20   The Doors - The Doors (Music From The Original...
# 21                               Michael Jackson - Bad
# 22                     Gianna Nannini - Maschi E Altri
# 23   Dire Straits & Mark Knopfler - Private Investi...
# 24   The London Symphony Orchestra And Chambre Choi...
# 25             Mina (3) - Cassiopea (Italian Songbook)
# 26       The Doors - Weird Scenes Inside The Gold Mine
# 27                                Jimi Hendrix - Blues
# 28                                 Queen - The Miracle
# 29                Marvin Gaye & Tammi Terrell - United
# 30            Pat Metheny Group - Still Life (Talking)
# 31                        Charlie Parker - Jam Session
# 32   Premiata Forneria Marconi - Come Ti Va In Riva...
# 33                                      The Doors - 13
# 34              Edoardo Bennato - Burattino Senza Fili
# 35                           Madonna - The First Album
# 36                                   Cariocas - Batida
# 37                             Claudio Baglioni - Solo
# 38                              The Beatles - Hey Jude
# 39                           Queen - News Of The World
# 40          Premiata Forneria Marconi - Live In U.S.A.
# 59   Original Collection Italy
# 60   Original Collection Italy
# 61            2023 Second Hand
# 62           Father Collection
# 63           Father Collection
# 64   Original Collection Italy
# 65   Original Collection Italy
# 66         Original Collection
# 67            2022 Second Hand
# 68            2021 Second Hand
# 69   Original Collection Italy
# 70         Original Collection
# 71           Father Collection
# 72            2022 Second Hand
# 73       2022 Second Hand Rita
# 74            2023 Second Hand
# 75   Original Collection Italy
# 76   Original Collection Italy
# 77            2023 Second Hand
# 78            2021 Second Hand
# 79            2023 Second Hand
# 80            2022 Second Hand
# 81            2023 Second Hand
# 82   Original Collection Italy
# 83   Original Collection Italy
# 84   Original Collection Italy
# 85            2021 Second Hand
# 86            2023 Second Hand
# 87            2021 Second Hand
# 88            2023 Second Hand
# 89            2021 Second Hand
# 90            2023 Second Hand
# 91   Original Collection Italy
# 92            2023 Second Hand
# 93            2022 Second Hand
# 94            2023 Second Hand
# 95   Original Collection Italy
# 96            2022 Second Hand
# 97            2023 Second Hand
# 98            2022 Second Hand
# 99            2022 Second Hand
# 100           2022 Second Hand
# 101          Father Collection
# 102  Original Collection Italy
# 103           2023 Second Hand
# 104           2023 Second Hand
# 105           2022 Second Hand
# 106           2022 Second Hand
# 107           2023 Second Hand
# 108           2021 Second Hand
# 109           2023 Second Hand
# 110  Original Collection Italy
# 111           2023 Second Hand
# 112  Original Collection Italy
# 113           2021 Second Hand
# 114           2022 Second Hand
# 115           2022 Second Hand
# 116  Original Collection Italy
# 117           2022 Second Hand
# 118           2022 Second Hand
# 119           2022 Second Hand
# 120           2022 Second Hand
# 121  Original Collection Italy
# 122           2023 Second Hand
# 123           2022 Second Hand
# 124          Father Collection
# 125                         45
# 126           2023 Second Hand
# 127           2022 Second Hand
# 128                         45
# 129  Original Collection Italy
# 130                         45
# 131  Original Collection Italy

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                            0
# Artist, Title, Label, Year, Format    0
# Min                                   0
# Median                                0
# Max                                   0
# Added                                 0
# dtype: int64

# %%
null_rows = df[df.isnull().any(axis=1)]
null_rows
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Artist, Title, Label, Year, Format, Min, Median, Max , Added]
# Index: []

# %%
df = df.drop(4)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>
#
# Change the name of the file with the today date.

# %%
# Inserts a new column named 'Artist'at index 0 and 'Title' at index 1 in the DataFrame df. 
# The initial values in these columns are set as empty strings ('').
df.insert(0, 'Artist', '')
df.insert(1, 'Title', '')

# %%
# Split the values in the 'Unnamed: 0' column using the delimiter ' - '
# The str.split() function returns a DataFrame with two columns ('Artist' and 'Title')
# containing the split values.
# By assigning this DataFrame to df[['Artist', 'Title']],
# the values are placed in the respective columns.
# The parameter n=1 indicates that the splitting should be done only once,
# resulting in a maximum of two parts.
# The expand=True parameter ensures that the result is returned as a DataFrame with two columns.
df[['Artist', 'Title']] = df['Unnamed: 0'].str.split(' - ', n=1, expand=True)

# Drops the 'Artist, Title, Label, Year, Format' column from the DataFrame df along the specified axis
# (axis=1 indicates the column axis).
# The inplace=True parameter ensures that the DataFrame is modified in place,
# without creating a new copy.
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head(1)
# Out:
#       Artist                       Title Artist, Title, Label, Year, Format
# 0  Battiato*  L'Era Del Cinghiale Bianco                             €21.76  \
#
#       Min   Median          Max               Added
# 0  €58.34  €178.04  3 months ago  Father Collection

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 7 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Artist                              132 non-null    object
#  1   Title                               132 non-null    object
#  2   Artist, Title, Label, Year, Format  132 non-null    object
#  3   Min                                 132 non-null    object
#  4   Median                              132 non-null    object
#  5   Max                                 132 non-null    object
#  6   Added                               132 non-null    object
# dtypes: object(7)
# memory usage: 7.3+ KB

# %%
df["Higher"] = df["Median"].str.replace("€", "").astype(float).round(2)

# %%
df["Min"] = df["Artist, Title, Label, Year, Format"].str.replace("€", "").astype(float).round(2)

# %%
df["Median"] = df["Median"].str.replace("€", "").astype(float).round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Artist                              132 non-null    object
#  1   Title                               132 non-null    object
#  2   Artist, Title, Label, Year, Format  132 non-null    object
#  3   Min                                 132 non-null    float64
#  4   Median                              132 non-null    float64
#  5   Max                                 132 non-null    object
#  6   Added                               132 non-null    object
#  7   Higher                              132 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 8.4+ KB

# %%
df = df.drop("Max ", axis=1)

# %%
df = df.drop("Artist, Title, Label, Year, Format", axis=1)

# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>
#
# Change the name of the file with the today date.

# %%
df = df.rename(columns={'Min':"Min_230711", 'Median': 'Median_230711', 'Higher': 'Higher_230711'})

# %%
df.head(1)
# Out:
#       Artist                       Title  Min_230711  Median_230711
# 0  Battiato*  L'Era Del Cinghiale Bianco       21.76         178.04  \
#
#                Added  Higher_230711
# 0  Father Collection         178.04

# %%
columns = df.columns.tolist()
columns
# Out:
# ['Artist', 'Title', 'Min_230711', 'Median_230711', 'Added', 'Higher_230711']

# %%
# Identify the column you want to move
column_to_move = 'Higher_230711'

# Remove the column from the list
columns.remove(column_to_move)

# Insert the column at the desired position
new_position = 4  # Move before the last column
columns.insert(new_position, column_to_move)

# Reorder the columns in the DataFrame
df = df[columns]

# %%
df.head(1)
# Out:
#       Artist                       Title  Min_230711  Median_230711
# 0  Battiato*  L'Era Del Cinghiale Bianco       21.76         178.04  \
#
#    Higher_230711              Added
# 0         178.04  Father Collection

# %%
#df = df.rename(columns={"Folder":"Collection"})

# %%
df = df.rename(columns={"Added":"Collection"})

# %%
df.head(1)
# Out:
#       Artist                       Title  Min_230711  Median_230711
# 0  Battiato*  L'Era Del Cinghiale Bianco       21.76         178.04  \
#
#    Higher_230711              Added
# 0         178.04  Father Collection

# %%
df.loc[df['Title'] == 'The Wall']
# Out:
#          Artist     Title  Min_230711  Median_230711  Higher_230711
# 132  Pink Floyd  The Wall       11.53          26.39          81.85  \
#
#                  Added
# 132  Father Collection

# %%
df.loc[len(df.index)] = ['Pink Floyd', 'The Wall', 11.53, 26.39, 81.85, 'Father Collection']

# %%
df.tail(1)
# Out:
#          Artist     Title  Min_230711  Median_230711  Higher_230711
# 132  Pink Floyd  The Wall       11.53          26.39          81.85  \
#
#                  Added
# 132  Father Collection

# %%
df.to_json("../../Discogs_Exports/VannaBe_Collection_Price/Final_YYMMDD/Final_230711.json", orient='columns', indent=None)
