# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>
#
# Follow the below instructions, and beware of the danger signs.

# %%
import pandas as pd
import re

# %%
pd.options.display.max_columns = None

# %%
# We should just copy the table in the following page https://www.discogs.com/user/VannaBe/collection?sort=max&sort_order=desc
# It is important to include all the columns and all the rows

price = pd.read_clipboard(sep="\t")

# %%
price
# Out:
#           Artist, Title, Label, Year, Format     Min  Median     Max
# 0                                        NaN     NaN     NaN      NaN  \
# 1     Battiato* - L'Era Del Cinghiale Bianco     NaN     NaN      NaN
# 2                                  LP, Album     NaN     NaN      NaN
# 3                           EMI 3C 064-18285     NaN     NaN      NaN
# 4                                 1979 Italy  €28.69  €57.93  €178.06
# ...                                      ...     ...     ...      ...
# 5918                                     NaN     NaN     NaN      NaN
# 5919                      Cover - Bruce Meek     NaN     NaN      NaN
# 5920                              Edit Notes     NaN     NaN      NaN
# 5921               Edit Record Cleaning Date     NaN     NaN      NaN
# 5922                Edit Record Cleaning Kit     NaN     NaN      NaN
#
#              Added             Folder  Rating  Album_Type  Style  Genre
# 0              NaN                NaN     NaN         NaN    NaN    NaN  \
# 1              NaN                NaN     NaN         NaN    NaN    NaN
# 2              NaN                NaN     NaN         NaN    NaN    NaN
# 3              NaN                NaN     NaN         NaN    NaN    NaN
# 4     2 months ago  Father Collection     NaN         NaN    NaN    NaN
# ...            ...                ...     ...         ...    ...    ...
# 5918           NaN                NaN     NaN         NaN    NaN    NaN
# 5919           NaN                NaN     NaN         NaN    NaN    NaN
# 5920           NaN                NaN     NaN         NaN    NaN    NaN
# 5921           NaN                NaN     NaN         NaN    NaN    NaN
# 5922           NaN                NaN     NaN         NaN    NaN    NaN
#
#       Recorded  Original Released  Artist_City  Artist_Country
# 0          NaN                NaN          NaN             NaN  \
# 1          NaN                NaN          NaN             NaN
# 2          NaN                NaN          NaN             NaN
# 3          NaN                NaN          NaN             NaN
# 4          NaN                NaN          NaN             NaN
# ...        ...                ...          ...             ...
# 5918       NaN                NaN          NaN             NaN
# 5919       NaN                NaN          NaN             NaN
# 5920       NaN                NaN          NaN             NaN
# 5921       NaN                NaN          NaN             NaN
# 5922       NaN                NaN          NaN             NaN
#
#       Artist_Region_State  Purchased  Year_Purchased  Shop  Shop_City
# 0                     NaN        NaN             NaN   NaN        NaN  \
# 1                     NaN        NaN             NaN   NaN        NaN
# 2                     NaN        NaN             NaN   NaN        NaN
# 3                     NaN        NaN             NaN   NaN        NaN
# 4                     NaN        NaN             NaN   NaN        NaN
# ...                   ...        ...             ...   ...        ...
# 5918                  NaN        NaN             NaN   NaN        NaN
# 5919                  NaN        NaN             NaN   NaN        NaN
# 5920                  NaN        NaN             NaN   NaN        NaN
# 5921                  NaN        NaN             NaN   NaN        NaN
# 5922                  NaN        NaN             NaN   NaN        NaN
#
#       Shop_Region_State  Shop_Country  Years active  Group  Group_Members
# 0                   NaN           NaN           NaN    NaN            NaN  \
# 1                   NaN           NaN           NaN    NaN            NaN
# 2                   NaN           NaN           NaN    NaN            NaN
# 3                   NaN           NaN           NaN    NaN            NaN
# 4                   NaN           NaN           NaN    NaN            NaN
# ...                 ...           ...           ...    ...            ...
# 5918                NaN           NaN           NaN    NaN            NaN
# 5919                NaN           NaN           NaN    NaN            NaN
# 5920                NaN           NaN           NaN    NaN            NaN
# 5921                NaN           NaN           NaN    NaN            NaN
# 5922                NaN           NaN           NaN    NaN            NaN
#
#       Instrument(s)  Instrument(s)_2  Instrument(s)_3  Instrument(s)_4
# 0               NaN              NaN              NaN              NaN  \
# 1               NaN              NaN              NaN              NaN
# 2               NaN              NaN              NaN              NaN
# 3               NaN              NaN              NaN              NaN
# 4               NaN              NaN              NaN              NaN
# ...             ...              ...              ...              ...
# 5918            NaN              NaN              NaN              NaN
# 5919            NaN              NaN              NaN              NaN
# 5920            NaN              NaN              NaN              NaN
# 5921            NaN              NaN              NaN              NaN
# 5922            NaN              NaN              NaN              NaN
#
#       Cover Art  Notes  Record Cleaning Date  Record Cleaning Kit
# 0           NaN    NaN                   NaN                  NaN
# 1           NaN    NaN                   NaN                  NaN
# 2           NaN    NaN                   NaN                  NaN
# 3           NaN    NaN                   NaN                  NaN
# 4           NaN    NaN                   NaN                  NaN
# ...         ...    ...                   ...                  ...
# 5918        NaN    NaN                   NaN                  NaN
# 5919        NaN    NaN                   NaN                  NaN
# 5920        NaN    NaN                   NaN                  NaN
# 5921        NaN    NaN                   NaN                  NaN
# 5922        NaN    NaN                   NaN                  NaN
#
# [5923 rows x 32 columns]

# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>
#
# Change the name of the file with the today date.

# %%
price.to_json('../../Discogs_Exports/VannaBe_Collection_Price/price_030723.json', orient='columns', indent=None)

# %%
df_price= pd.read_json('../../Discogs_Exports/VannaBe_Collection_Price/price_030723.json')

# %%
df = df_price.iloc[:, :6]

# %%
df
# Out:
#           Artist, Title, Label, Year, Format     Min  Median     Max
# 0                                       None    None    None     None  \
# 1     Battiato* - L'Era Del Cinghiale Bianco    None    None     None
# 2                                  LP, Album    None    None     None
# 3                           EMI 3C 064-18285    None    None     None
# 4                                 1979 Italy  €28.69  €57.93  €178.06
# ...                                      ...     ...     ...      ...
# 5918                                    None    None    None     None
# 5919                      Cover - Bruce Meek    None    None     None
# 5920                              Edit Notes    None    None     None
# 5921               Edit Record Cleaning Date    None    None     None
# 5922                Edit Record Cleaning Kit    None    None     None
#
#              Added             Folder
# 0             None               None
# 1             None               None
# 2             None               None
# 3             None               None
# 4     2 months ago  Father Collection
# ...            ...                ...
# 5918          None               None
# 5919          None               None
# 5920          None               None
# 5921          None               None
# 5922          None               None
#
# [5923 rows x 6 columns]

# %%
# Find the rows that contain the Euro symbol
euro_rows = df[df.apply(lambda row: row.astype(str).str.contains('€').any(), axis=1)].index

# %%
euro_rows
# Out:
# Index([   4,   42,   90,  131,  178,  190,  232,  279,  316,  356,
#        ...
#        5124, 5181, 5225, 5261, 5294, 5337, 5385, 5417, 5449, 5488],
#       dtype='int64', length=133)

# %%
cell_value = df.at[178, 'Artist, Title, Label, Year, Format']
print(cell_value)
# Out:
# LIVE 3-LP
# PINK FLOYD
# Delicate Sound of Thunder
# Remixed from the original master tapes
# Heavyweight 180g Vinyl
# 24-page Booklet
# 23 songs
# Approx. 2 1/2 hours
# Features 9 songs
# not included on the
# 1988 2-LP.
#
# Edit Record Cleaning Date
# Edit Record Cleaning Kit
#
# Pink Floyd - The Wall
# 2xLP, Album
# Columbia, Columbia PC2 36183, 36183
# 1979 Canada	€11.74	€26.68	€82.75	2 months ago	Father Collection
# Good Plus (G+)
#
# Very Good (VG)
#
# Tribute Album
#
# Prog Rock
#
# Rock
#
# Britannia Row
# London, England, UK
# Super Bear
# Nice, France
# Miraval (Correns)
# 30th Street
# New York, New York, USA
# Producers Workshop
# Los Angeles
# Cherokee
# Hollywood)
#
# 1979
#
# London
#
# UK
#
# England
#
# In-Store
#
# Unknown
#
# Unknown
#
# Unknown
#
# Unknown
#
# Italy
#
# 1965–1994
# 2005
# 2007
# 2013–2014
# 2022
#
# Yes
#
# Roger Waters
# David Gilmour
# Nick Mason
# Richard Wright
#
# Roger Waters – vocals, bass guitar, synthesizer, acoustic guitar, electric guitar
# David Gilmour – vocals, electric,and acoustic guitars, bass guitar,ARP Quadra synthesizers
#
# Nick Mason – drums and percussion
# Richard Wright – piano, Hammond organ, Prophet-5, ARP Quadra, Minimoog synthesizers, Fender Rhodes, Wurlitzer electric pianos, clavinet.
#
# Bob Ezrin - piano, Hammond organ and harmonium, Prophet-5
# Jeff Porcaro - drums
# Lee Ritenour – rhythm guitar, acoustic guitar
# Fred Mandel – Hammond organ
# Bobbye Hall – congas and bongos
# Frank Marocco – concertina
# Larry Williams – clarinet
#
# New York Orchestra & Opera
# Harry Waters – child's voice on Goodbye Blue Sky"

# %%
# Create a list of rows to keep, including the three rows before each Euro row
rows_to_keep = []
for row in euro_rows:
    rows_to_keep.extend(range(row - 3, row + 1))

# %%
# Keep only the selected rows
df = df.loc[rows_to_keep]

# %%
df = df.reset_index(drop=True)

# %%
# Define the row indices to drop
rows_to_drop = []
for i in range(1, len(df), 4):
    rows_to_drop.extend([i, i+1])

# Drop the rows from the DataFrame
df = df.drop(rows_to_drop)

# Reset the index of the DataFrame
df = df.reset_index(drop=True)

# %%
# Iterate over the rows in the DataFrame
for i in range(1, len(df)):
    # Check if the row index is odd
    if i % 2 == 1:
        # Copy the value from the previous row's first column and paste it into the current row's first column
        df.iloc[i, 0] = df.iloc[i-1, 0]

# %%
# Iterate over the rows in the DataFrame
for i in range(1, len(df)):
    # Check if the row index is odd
    if i % 2 == 1:
        # Copy the value from the previous row's first column and paste it into the current row's first column
        df.iloc[i, 0] = df.iloc[i-1, 0]

# Delete rows with even indices
df = df.drop(df.index[::2])

# Reset the index of the DataFrame
df = df.reset_index(drop=True)

# %%
df
# Out:
#                     Artist, Title, Label, Year, Format     Min  Median
# 0               Battiato* - L'Era Del Cinghiale Bianco  €28.69  €57.93  \
# 1             Premiata Forneria Marconi - Per Un Amico  €14.84  €49.86
# 2                                      New Trolls - UT  €13.12  €50.00
# 3               Pink Floyd - Delicate Sound Of Thunder  €45.00  €56.45
# 4               Photography By [Package] – Dimo Safari    None    None
# ..                                                 ...     ...     ...
# 128            Culture Club - From Luxury To Heartache   €1.00   €2.33
# 129  Fernandez Pray Und Sein Orchester - Midnight I...   €1.90   €4.74
# 130          Riccardo Cocciante - I Momenti Dell'Amore   €1.00   €2.00
# 131                    Mungo Jerry - In The Summertime   €0.49   €1.73
# 132   Santo & Johnny - Il Padrino Famosi Temi Da Films   €2.77   €3.05
#
#         Max               Added                     Folder
# 0    €178.06       2 months ago          Father Collection
# 1    €148.39       2 months ago          Father Collection
# 2    €125.00       2 months ago          Father Collection
# 3     €89.00  about 1 month ago        Original Collection
# 4       None               None                       None
# ..       ...                ...                        ...
# 128    €5.75  about 1 month ago           2022 Second Hand
# 129    €5.68  about 1 month ago                         45
# 130    €4.00  about 1 month ago  Original Collection Italy
# 131    €3.96  about 1 month ago                         45
# 132    €3.33  about 1 month ago  Original Collection Italy
#
# [133 rows x 6 columns]

# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>
#
# Change the name of the file with the today date.

# %%
# Inserts a new column named 'Artist'at index 0 and 'Title' at index 1 in the DataFrame df. 
# The initial values in these columns are set as empty strings ('').
df.insert(0, 'Artist', '')
df.insert(1, 'Title', '')

# %%
df
# Out:
#     Artist Title                 Artist, Title, Label, Year, Format     Min
# 0                            Battiato* - L'Era Del Cinghiale Bianco  €28.69  \
# 1                          Premiata Forneria Marconi - Per Un Amico  €14.84
# 2                                                   New Trolls - UT  €13.12
# 3                            Pink Floyd - Delicate Sound Of Thunder  €45.00
# 4                            Photography By [Package] – Dimo Safari    None
# ..     ...   ...                                                ...     ...
# 128                         Culture Club - From Luxury To Heartache   €1.00
# 129               Fernandez Pray Und Sein Orchester - Midnight I...   €1.90
# 130                       Riccardo Cocciante - I Momenti Dell'Amore   €1.00
# 131                                 Mungo Jerry - In The Summertime   €0.49
# 132                Santo & Johnny - Il Padrino Famosi Temi Da Films   €2.77
#
#      Median     Max               Added                     Folder
# 0    €57.93  €178.06       2 months ago          Father Collection
# 1    €49.86  €148.39       2 months ago          Father Collection
# 2    €50.00  €125.00       2 months ago          Father Collection
# 3    €56.45   €89.00  about 1 month ago        Original Collection
# 4      None     None               None                       None
# ..      ...      ...                ...                        ...
# 128   €2.33    €5.75  about 1 month ago           2022 Second Hand
# 129   €4.74    €5.68  about 1 month ago                         45
# 130   €2.00    €4.00  about 1 month ago  Original Collection Italy
# 131   €1.73    €3.96  about 1 month ago                         45
# 132   €3.05    €3.33  about 1 month ago  Original Collection Italy
#
# [133 rows x 8 columns]

# %%
# Split the values in the 'Unnamed: 0' column using the delimiter ' - '
# The str.split() function returns a DataFrame with two columns ('Artist' and 'Title')
# containing the split values.
# By assigning this DataFrame to df[['Artist', 'Title']],
# the values are placed in the respective columns.
# The parameter n=1 indicates that the splitting should be done only once,
# resulting in a maximum of two parts.
# The expand=True parameter ensures that the result is returned as a DataFrame with two columns.
df[['Artist', 'Title']] = df['Artist, Title, Label, Year, Format'].str.split(' - ', n=1, expand=True)

# Drops the 'Artist, Title, Label, Year, Format' column from the DataFrame df along the specified axis
# (axis=1 indicates the column axis).
# The inplace=True parameter ensures that the DataFrame is modified in place,
# without creating a new copy.
df.drop('Artist, Title, Label, Year, Format', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                    Artist                       Title     Min
# 0                               Battiato*  L'Era Del Cinghiale Bianco  €28.69  \
# 1               Premiata Forneria Marconi                Per Un Amico  €14.84
# 2                              New Trolls                          UT  €13.12
# 3                              Pink Floyd   Delicate Sound Of Thunder  €45.00
# 4  Photography By [Package] – Dimo Safari                        None    None
#
#    Median     Max               Added               Folder
# 0  €57.93  €178.06       2 months ago    Father Collection
# 1  €49.86  €148.39       2 months ago    Father Collection
# 2  €50.00  €125.00       2 months ago    Father Collection
# 3  €56.45   €89.00  about 1 month ago  Original Collection
# 4    None     None               None                 None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Artist  133 non-null    object
#  1   Title   132 non-null    object
#  2   Min     132 non-null    object
#  3   Median  132 non-null    object
#  4   Max     132 non-null    object
#  5   Added   132 non-null    object
#  6   Folder  132 non-null    object
# dtypes: object(7)
# memory usage: 7.4+ KB

# %%
df["Higher"] = df["Max "].str.replace("€", "").astype(float).round(2)

# %%
df["Min"] = df["Min"].str.replace("€", "").astype(float).round(2)

# %%
df["Median"] = df["Median"].str.replace("€", "").astype(float).round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Artist  133 non-null    object
#  1   Title   132 non-null    object
#  2   Min     132 non-null    float64
#  3   Median  132 non-null    float64
#  4   Max     132 non-null    object
#  5   Added   132 non-null    object
#  6   Folder  132 non-null    object
#  7   Higher  132 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 8.4+ KB

# %%
df = df.drop("Max ", axis=1)

# %%
df = df.drop("Added", axis=1)

# %% [markdown]
# # ⚠️ <span style="color: #FF6961">Warning</span>
#
# Change the name of the file with the today date.

# %%
df = df.rename(columns={'Min':"Min_230703", 'Median': 'Median_230703', 'Higher': 'Higher_230703'})

# %%
df
# Out:
#                                      Artist                            Title
# 0                                 Battiato*       L'Era Del Cinghiale Bianco  \
# 1                 Premiata Forneria Marconi                     Per Un Amico
# 2                                New Trolls                               UT
# 3                                Pink Floyd        Delicate Sound Of Thunder
# 4    Photography By [Package] – Dimo Safari                             None
# ..                                      ...                              ...
# 128                            Culture Club         From Luxury To Heartache
# 129       Fernandez Pray Und Sein Orchester                  Midnight In Rio
# 130                      Riccardo Cocciante             I Momenti Dell'Amore
# 131                             Mungo Jerry                In The Summertime
# 132                          Santo & Johnny  Il Padrino Famosi Temi Da Films
#
#      Min_230703  Median_230703                     Folder  Higher_230703
# 0         28.69          57.93          Father Collection         178.06
# 1         14.84          49.86          Father Collection         148.39
# 2         13.12          50.00          Father Collection         125.00
# 3         45.00          56.45        Original Collection          89.00
# 4           NaN            NaN                       None            NaN
# ..          ...            ...                        ...            ...
# 128        1.00           2.33           2022 Second Hand           5.75
# 129        1.90           4.74                         45           5.68
# 130        1.00           2.00  Original Collection Italy           4.00
# 131        0.49           1.73                         45           3.96
# 132        2.77           3.05  Original Collection Italy           3.33
#
# [133 rows x 6 columns]

# %%
columns = df.columns.tolist()
columns
# Out:
# ['Artist', 'Title', 'Min_230703', 'Median_230703', 'Folder', 'Higher_230703']

# %%
# Identify the column you want to move
column_to_move = 'Higher_230703'

# Remove the column from the list
columns.remove(column_to_move)

# Insert the column at the desired position
new_position = 4  # Move before the last column
columns.insert(new_position, column_to_move)

# Reorder the columns in the DataFrame
df = df[columns]

# %%
df.head()
# Out:
#                                    Artist                       Title
# 0                               Battiato*  L'Era Del Cinghiale Bianco  \
# 1               Premiata Forneria Marconi                Per Un Amico
# 2                              New Trolls                          UT
# 3                              Pink Floyd   Delicate Sound Of Thunder
# 4  Photography By [Package] – Dimo Safari                        None
#
#    Min_230703  Median_230703  Higher_230703               Folder
# 0       28.69          57.93         178.06    Father Collection
# 1       14.84          49.86         148.39    Father Collection
# 2       13.12          50.00         125.00    Father Collection
# 3       45.00          56.45          89.00  Original Collection
# 4         NaN            NaN            NaN                 None

# %%
df = df.rename(columns={"Folder":"Collection"})

# %%
df.head()
# Out:
#                                    Artist                       Title
# 0                               Battiato*  L'Era Del Cinghiale Bianco  \
# 1               Premiata Forneria Marconi                Per Un Amico
# 2                              New Trolls                          UT
# 3                              Pink Floyd   Delicate Sound Of Thunder
# 4  Photography By [Package] – Dimo Safari                        None
#
#    Min_230703  Median_230703  Higher_230703           Collection
# 0       28.69          57.93         178.06    Father Collection
# 1       14.84          49.86         148.39    Father Collection
# 2       13.12          50.00         125.00    Father Collection
# 3       45.00          56.45          89.00  Original Collection
# 4         NaN            NaN            NaN                 None

# %%
df = df.drop(4)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#                       Artist                       Title  Min_230703
# 0                  Battiato*  L'Era Del Cinghiale Bianco       28.69  \
# 1  Premiata Forneria Marconi                Per Un Amico       14.84
# 2                 New Trolls                          UT       13.12
# 3                 Pink Floyd   Delicate Sound Of Thunder       45.00
# 4  Premiata Forneria Marconi           L'Isola Di Niente       10.11
#
#    Median_230703  Higher_230703           Collection
# 0          57.93         178.06    Father Collection
# 1          49.86         148.39    Father Collection
# 2          50.00         125.00    Father Collection
# 3          56.45          89.00  Original Collection
# 4          30.33          80.88    Father Collection

# %%
df.to_json("../../Discogs_Exports/VannaBe_Collection_Price/Final_YYMMDD/Final_230703.json", orient='columns', indent=None)

# %%
df.loc[len(df.index)] = ['Pink Floyd', 'The Wall', 11.74, 26.68, 82.75, 'Father Collection']

# %%
df.tail()
# Out:
#                                 Artist                            Title
# 128  Fernandez Pray Und Sein Orchester                  Midnight In Rio  \
# 129                 Riccardo Cocciante             I Momenti Dell'Amore
# 130                        Mungo Jerry                In The Summertime
# 131                     Santo & Johnny  Il Padrino Famosi Temi Da Films
# 132                         Pink Floyd                         The Wall
#
#      Min_230703  Median_230703  Higher_230703                 Collection
# 128        1.90           4.74           5.68                         45
# 129        1.00           2.00           4.00  Original Collection Italy
# 130        0.49           1.73           3.96                         45
# 131        2.77           3.05           3.33  Original Collection Italy
# 132       11.74          26.68          82.75          Father Collection

# %%
df.to_json("../../Discogs_Exports/VannaBe_Collection_Price/Final_YYMMDD/Final_230703.json", orient='columns', indent=None)
