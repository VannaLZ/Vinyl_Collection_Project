# %%
import pandas as pd
import numpy as np
import re

# %%
# define column names
columns = ['Catalog_ID', 'Artist', 'Title', 'Label', 'Format','Vacio','Released', 'Release_id', 'Notes', 'Inserted_Date']

# read the CSV file with explicit column names
df = pd.read_csv('../Discogs_Exports/VannaBe-wantlist-20230420-0857.csv', names=columns, skiprows=1)

# %%
df.head(2)
# Out:
#   Catalog_ID        Artist                                              Title
# 0   88.122-l    Supertramp                               Crime Of The Century  \
# 1    88674 E  Rick Wakeman  The Myths And Legends Of King Arthur And The K...
#
#          Label          Format  Vacio  Released  Release_id
# 0  A&M Records       LP, Album    NaN      1974     1460333  \
# 1  A&M Records  LP, Album, Gat    NaN      1975     5278224
#
#                                               Notes        Inserted_Date
# 0  Lowest:\t€4.10\nMedian:\t€7.50\nHighest:\t€20.00  2023-04-20 03:04:12
# 1   Lowest:\t€2.00\nMedian:\t€3.50\nHighest:\t€5.39  2023-04-20 08:01:25

# %%
df.shape
# Out:
# (67, 10)

# %%
df.dtypes
# Out:
# Catalog_ID        object
# Artist            object
# Title             object
# Label             object
# Format            object
# Vacio            float64
# Released           int64
# Release_id         int64
# Notes             object
# Inserted_Date     object
# dtype: object

# %%
df['Inserted_Date'] = df['Inserted_Date'].str[:10]

# %%
df.sample(2)
# Out:
#    Catalog_ID       Artist                Title                 Label
# 24  89.791-IE  Jethro Tull              Benefit  Chrysalis, Chrysalis  \
# 20   28.438-I  Jethro Tull  Songs From The Wood             Chrysalis
#
#        Format  Vacio  Released  Release_id
# 24  LP, Album    NaN      1970    19248337  \
# 20  LP, Album    NaN      1977     1727012
#
#                                                Notes Inserted_Date
# 24                                               NaN    2023-04-20
# 20  Lowest:\t€5.90\nMedian:\t€9.99\nHighest:\t€30.00    2023-04-20

# %%
df.isnull().sum()
# Out:
# Catalog_ID        0
# Artist            0
# Title             0
# Label             0
# Format            0
# Vacio            67
# Released          0
# Release_id        0
# Notes             2
# Inserted_Date     0
# dtype: int64

# %%
#There are 67 rows and 67 null so I can remove this column, on top I know I did not track it in the Wishlist
df.drop('Vacio', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Catalog_ID', 'Artist', 'Title', 'Label', 'Format', 'Released',
#        'Release_id', 'Notes', 'Inserted_Date'],
#       dtype='object')

# %%
df.describe().round()
# Out:
#        Released  Release_id
# count      67.0        67.0
# mean     1982.0   5770953.0
# std        15.0   5391246.0
# min      1968.0    409894.0
# 25%      1974.0   1872016.0
# 50%      1977.0   4198115.0
# 75%      1980.0   7424028.0
# max      2021.0  20929789.0

# %%
df.describe(include=['O'])
# Out:
#        Catalog_ID         Artist                 Title        Label
# count          67             67                    67           67  \
# unique         67             24                    67           44
# top      88.122-l  Mike Oldfield  Crime Of The Century  A&M Records
# freq            1              8                     1            4
#
#            Format                                            Notes
# count          67                                               65  \
# unique         12                                               64
# top     LP, Album  Lowest:\t€2.00\nMedian:\t€3.50\nHighest:\t€5.39
# freq           32                                                2
#
#        Inserted_Date
# count             67
# unique             1
# top       2023-04-20
# freq              67

# %%
artists = sorted(df['Artist'].unique())
artists
# Out:
# ['Cai (4)',
#  'Canarios',
#  'Electric Light Orchestra',
#  'Emerson, Lake & Palmer',
#  'Frank Zappa And The Mothers',
#  'Genesis',
#  'Gotic',
#  'Guadalquivir',
#  'Iceberg (2)',
#  'Imán, Califato Independiente',
#  'Jarabe De Palo',
#  'Jethro Tull',
#  'La Máquina De Hacer Pájaros',
#  'Marillion',
#  'Mike Oldfield',
#  'New Trolls',
#  'Premiata Forneria Marconi',
#  'Procol Harum',
#  'Rick Wakeman',
#  'Supertramp',
#  'The Alan Parsons Project',
#  'Triana (2)',
#  'Triumvirat',
#  'Yes']

# %%
df['Artist'] = df['Artist'].replace({'Cai (4)': 'Cai', 'Iceberg (2)': 'Iceberg', 'Triana (2)': 'Triana'})

# %%
artists = sorted(df['Artist'].unique())
artists
# Out:
# ['Cai',
#  'Canarios',
#  'Electric Light Orchestra',
#  'Emerson, Lake & Palmer',
#  'Frank Zappa And The Mothers',
#  'Genesis',
#  'Gotic',
#  'Guadalquivir',
#  'Iceberg',
#  'Imán, Califato Independiente',
#  'Jarabe De Palo',
#  'Jethro Tull',
#  'La Máquina De Hacer Pájaros',
#  'Marillion',
#  'Mike Oldfield',
#  'New Trolls',
#  'Premiata Forneria Marconi',
#  'Procol Harum',
#  'Rick Wakeman',
#  'Supertramp',
#  'The Alan Parsons Project',
#  'Triana',
#  'Triumvirat',
#  'Yes']

# %%
df = df.sort_values(by='Artist')

# %%
df.head(10)
# Out:
#             Catalog_ID                    Artist
# 37              LC-001                       Cai  \
# 28           EPC 85054                       Cai
# 27           EPC 84218                       Cai
# 5   87905 XD, 87905-XD                  Canarios
# 36           JETLX 500  Electric Light Orchestra
# 52           25.144-XD  Electric Light Orchestra
# 53   28 273-I, 28273-I  Electric Light Orchestra
# 33           85.382-SE    Emerson, Lake & Palmer
# 35   86.230-I, 86230.I    Emerson, Lake & Palmer
# 34           85.527-SE    Emerson, Lake & Palmer
#
#                                     Title
# 37  Mas Allá De Nuestras Mentes Diminutas  \
# 28                Canción De La Primavera
# 27                          Noche Abierta
# 5                                  Ciclos
# 36                              Discovery
# 52                        Out Of The Blue
# 53                     A New World Record
# 33                 Emerson, Lake & Palmer
# 35                                Trilogy
# 34                                 Tarkus
#
#                                                 Label          Format
# 37                             Lacochu, Trova Records       LP, Album  \
# 28                                               Epic       LP, Album
# 27                                               Epic  LP, Album, Gat
# 5                                      Ariola, Ariola     2xLP, Album
# 36                                        Jet Records  LP, Album, Gat
# 52                United Artists Records, Jet Records     2xLP, Album
# 53  United Artists Records, Jet Records, United Ar...  LP, Album, Smo
# 33                                     Island Records       LP, Album
# 35                     Island Records, Island Records  LP, Album, Gat
# 34                                     Island Records  LP, Album, Gat
#
#     Released  Release_id                                              Notes
# 37      1978     1819813  Lowest:\t€120.00\nMedian:\t€120.00\nHighest:\t...  \
# 28      1981     4007248  Lowest:\t€18.00\nMedian:\t€24.95\nHighest:\t€5...
# 27      1980     1549999  Lowest:\t€14.00\nMedian:\t€28.99\nHighest:\t€5...
# 5       1974      745518  Lowest:\t€8.00\nMedian:\t€30.91\nHighest:\t€70.00
# 36      1979     1284470   Lowest:\t€2.00\nMedian:\t€5.75\nHighest:\t€10.00
# 52      1978     2843993   Lowest:\t€1.50\nMedian:\t€9.99\nHighest:\t€17.99
# 53      1976     1924220    Lowest:\t€1.40\nMedian:\t€4.50\nHighest:\t€8.00
# 33      1971     4928694   Lowest:\t€3.99\nMedian:\t€9.00\nHighest:\t€14.00
# 35      1972     3582008   Lowest:\t€2.00\nMedian:\t€6.92\nHighest:\t€15.00
# 34      1971     3289667  Lowest:\t€5.99\nMedian:\t€10.00\nHighest:\t€16.50
#
#    Inserted_Date
# 37    2023-04-20
# 28    2023-04-20
# 27    2023-04-20
# 5     2023-04-20
# 36    2023-04-20
# 52    2023-04-20
# 53    2023-04-20
# 33    2023-04-20
# 35    2023-04-20
# 34    2023-04-20

# %%
# define regex pattern
pattern = r"Lowest:\s*([^\n]+)\nMedian:\s*([^\n]+)\nHighest:\s*([^\n]+)"

# loop through each row in the dataframe
for i in range(len(df)):
    # check if cell in 'Notes' column is a string
    if isinstance(df.loc[i, 'Notes'], str):
        # apply regex pattern and create new columns for lowest, median, and highest prices
        match = re.findall(pattern, df.loc[i, 'Notes'])
        if match:
            df.loc[i, 'Lowest_Price'] = match[0][0]
            df.loc[i, 'Median_Price'] = match[0][1]
            df.loc[i, 'Highest_Price'] = match[0][2]

# %%
df.sample(3)
# Out:
#                 Catalog_ID                       Artist               Title
# 57  V 3166, 00602557256703                Mike Oldfield  Return To Ommadawn  \
# 43               17.1302/6                        Gotic             Escenes
# 41                 SUP-853  La Máquina De Hacer Pájaros           Películas
#
#                                      Label          Format  Released
# 57  Virgin EMI Records, Virgin EMI Records  LP, Album, 180      2017  \
# 43                               Movieplay       LP, Album      1978
# 41                                Microfon       LP, Album      1977
#
#     Release_id                                              Notes
# 57     9679634  Lowest:\t€17.05\nMedian:\t€32.49\nHighest:\t€8...  \
# 43     3241016  Lowest:\t€24.90\nMedian:\t€73.94\nHighest:\t€9...
# 41     3506667  Lowest:\t€37.31\nMedian:\t€55.00\nHighest:\t€1...
#
#    Inserted_Date Lowest_Price Median_Price Highest_Price
# 57    2023-04-20       €17.05       €32.49        €88.00
# 43    2023-04-20       €24.90       €73.94        €95.00
# 41    2023-04-20       €37.31       €55.00       €113.75

# %%
df.to_csv('../Discogs_Exports/Wannalist_20_04_23.csv', index=0)
