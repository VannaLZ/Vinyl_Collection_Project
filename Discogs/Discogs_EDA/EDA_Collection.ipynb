# %%
import pandas as pd
import numpy as np
import re

# %%
# define column names
columns = ['Catalog_ID', 'Artist', 'Title', 'Label', 'Format',
           'Rating','Released', 'Release_id','Collection_Folder','Date_Added',
           'Album_Type', 'Style','Genre','Recorded','Original_Released',
           'Artist_City','Artist_Country','Artist_Region_State',
           'Purchased','Year_Purchased', 'Shop', 'Shop_City', 'Shop_Region_State',
           'Shop_Country','Years_Active', 'Group','Group_Members',
           'Instrument(s)','Instrument(s)_2', 'Instrument(s)_3',
            'Instrument(s)_4', 'Media_Condition', 'Sleeve_Condition', 'Cover_Art', 'Notes']
df = pd.read_csv('../Discogs_Exports/VannaBe-collection-20230426-0355.csv', names=columns, skiprows=1)
# read the CSV file with explicit column names

# %%
df.head(2)
# Out:
#   Catalog_ID          Artist                 Title                     Label
# 0     350203  Billie Holiday         Lady In Satin  20th Century Masterworks  \
# 1   88.122-l      Supertramp  Crime Of The Century               A&M Records
#
#              Format  Rating  Released  Release_id    Collection_Folder
# 0  LP, Ltd, RE, Pur       4      2020    15999105  Original Collection  \
# 1         LP, Album       3      1974     1460333     2023 Second Hand
#
#             Date_Added    Album_Type Style                          Genre
# 0  2023-04-24 04:00:30    Collection  Jazz                           Jazz  \
# 1  2023-04-24 01:34:17  Studio Album  Rock  Art Rock, Prog Rock, Pop Rock
#
#                                             Recorded  Original_Released
# 0                                            Unknown               1958  \
# 1  Trident Studio\nRamport Studio\nScorpio Studio...               1974
#
#     Artist_City Artist_Country Artist_Region_State Purchased Year_Purchased
# 0  Philadelphia            USA        Pennsylvania    Online           2021  \
# 1        London             UK             England  In-Store           2023
#
#            Shop Shop_City    Shop_Region_State Shop_Country
# 0        Amazon       NaN                  NaN        Spain  \
# 1  Discs Oldies  Valencia  Valencian Community        Spain
#
#                             Years_Active Group
# 0                              1930–1959    No  \
# 1  1970–1988\n1996–2002\n2010–2012\n2015   Yes
#
#                                        Group_Members
# 0                                                NaN  \
# 1  Rick Davies\nRoger Hodgson\nJohn Anthony Helli...
#
#                                        Instrument(s)
# 0  Vocal - Billie Holiday\nviolin and concertmast...  \
# 1  Rick Davies – vocals, keyboards, harmonica\nRo...
#
#                                      Instrument(s)_2
# 0  cello - David Soyer, Maurice Brown\nHarp - Jan...  \
# 1  Christine Helliwell – backing vocals (3)\nScot...
#
#                                      Instrument(s)_3 Instrument(s)_4
# 0  Trombone - J.J. Johnson, Urbie Green\nbass tro...             NaN  \
# 1                                                NaN             NaN
#
#         Media_Condition      Sleeve_Condition
# 0  Near Mint (NM or M-)  Near Mint (NM or M-)  \
# 1              Fair (F)              Poor (P)
#
#                                            Cover_Art
# 0      Photo by Michael Ochs Archives / Getty Images  \
# 1  Art Direction – Fabio Nicoli\nDesign [Sleeve],...
#
#                                                Notes
# 0  Originally released as Lady in Satin (Columbia...
# 1  Recorded at Trident, Ramport Studios and Scorp...

# %%
df.tail(2)
# Out:
#                 Catalog_ID         Artist           Title           Label
# 38  I - 204.500, I·204 500  Mike Oldfield  Five Miles Out  Virgin, Virgin  \
# 39         V 2640, 210 707  Mike Oldfield          Amarok  Virgin, Virgin
#
#             Format  Rating  Released  Release_id Collection_Folder
# 38  LP, Album, Gat       3      1982     1777229  2023 Second Hand  \
# 39       LP, Album       4      1990      552362  2022 Second Hand
#
#              Date_Added    Album_Type                Style
# 38  2023-04-23 23:55:30  Studio Album  Pop Rock, Prog Rock  \
# 39  2023-04-24 05:46:57  Studio Album            Prog Rock
#
#                                                 Genre
# 38                                               Rock  \
# 39  Instrumental rock, Progrock, Experimental rock...
#
#                                              Recorded  Original_Released
# 38  Tilehouse \nDenham, Buckinghamshire, England, ...               1982  \
# 39  Roughwood Croft, \n\nChalfont St Giles and CTS...               1990
#
#    Artist_City Artist_Country Artist_Region_State Purchased Year_Purchased
# 38     Reading             UK             England  In-Store           2023  \
# 39     Reading             UK  Berkshire, England  In-Store           2022
#
#             Shop  Shop_City    Shop_Region_State Shop_Country Years_Active
# 38  Discs Oldies   Valencia  Valencian Community        Spain    1967–2018  \
# 39  Daily Record  Barcelona            Catalonia        Spain    1967–2018
#
#    Group Group_Members                                      Instrument(s)
# 38    No           NaN  Drums – Graham Broad. Guitar – Rick Fenn, Guit...  \
# 39    No           NaN  Bowed Guitar, Acoustic Guitar, Electric Guitar...
#
#                                       Instrument(s)_2
# 38                                                NaN  \
# 39  Shoes, Hoover, Glockenspiel, Marimba, Bodhran,...
#
#                                       Instrument(s)_3
# 38                                                NaN  \
# 39  Punch Ball and Club, Spoons, Referee's Whistle...
#
#                                       Instrument(s)_4 Media_Condition
# 38                                                NaN  Very Good (VG)  \
# 39  Rototom, Cabasa, Bongos, Orchestral Bass Drum,...  Good Plus (G+)
#
#    Sleeve_Condition                                          Cover_Art
# 38         Good (G)  Design [Sleeve Design] – Mike Oldfield\nPainti...  \
# 39         Good (G)                Cover, Liner Notes – William Murray
#
#                                                 Notes
# 38                         ℗ 1982 Virgin Records Ltd.
# 39  In a parody of listening instructions on the s...

# %%
df.shape
# Out:
# (40, 35)

# %%
df.dtypes
# Out:
# Catalog_ID             object
# Artist                 object
# Title                  object
# Label                  object
# Format                 object
# Rating                  int64
# Released                int64
# Release_id              int64
# Collection_Folder      object
# Date_Added             object
# Album_Type             object
# Style                  object
# Genre                  object
# Recorded               object
# Original_Released       int64
# Artist_City            object
# Artist_Country         object
# Artist_Region_State    object
# Purchased              object
# Year_Purchased         object
# Shop                   object
# Shop_City              object
# Shop_Region_State      object
# Shop_Country           object
# Years_Active           object
# Group                  object
# Group_Members          object
# Instrument(s)          object
# Instrument(s)_2        object
# Instrument(s)_3        object
# Instrument(s)_4        object
# Media_Condition        object
# Sleeve_Condition       object
# Cover_Art              object
# Notes                  object
# dtype: object

# %%
pd.set_option('display.max_columns', None)

# %%
df.sample(2)
# Out:
#              Catalog_ID         Artist                Title           Label
# 37  87.541-I , 87541-I   Mike Oldfield       Tubular Bells   Virgin, Virgin  \
# 33             NL 33153        Various  I Supergruppi Vol.1             RCA
#
#            Format  Rating  Released  Release_id  Collection_Folder
# 37  LP, Album, RE       5      1983     6168450   2021 Second Hand  \
# 33       LP, Comp       2      1980     5506737  Father Collection
#
#              Date_Added    Album_Type                Style      Genre
# 37  2023-04-21 02:47:38  Studio Album            Prog Rock       Rock  \
# 33  2023-04-24 02:19:35    Collection  Pop Rock, Prog Rock  Rock, Pop
#
#                                              Recorded  Original_Released
# 37  The Manor\nShipton-on-Cherwell, Oxfordshire, E...               1974  \
# 33                                                NaN               1980
#
#    Artist_City Artist_Country Artist_Region_State Purchased Year_Purchased
# 37     Reading             UK             England  In-Store           2021  \
# 33         NaN          Italy                 NaN  In-Store           1980
#
#              Shop  Shop_City Shop_Region_State Shop_Country Years_Active
# 37  Daily Records  Barcelona         Catalonia        Spain    1967–2018  \
# 33        Unknown    Unknown           Unknown        Italy          NaN
#
#    Group Group_Members                                      Instrument(s)
# 37    No           NaN  Kevin Ayers – bass guitar\nDavid Bedford – gra...  \
# 33    No           NaN                                                NaN
#
#                                       Instrument(s)_2
# 37  Steve Hillage – electric guitar\nSimon Ingram ...  \
# 33                                                NaN
#
#                                       Instrument(s)_3
# 37  Mike Oldfield – acoustic and electric guitars,...  \
# 33                                                NaN
#
#                                       Instrument(s)_4 Media_Condition
# 37  Girlie Chorus: Sarah Greaves, Kathy Williams, ...  Good Plus (G+)  \
# 33                                                NaN        Fair (F)
#
#    Sleeve_Condition                                     Cover_Art
# 37         Fair (F)  Design [Sleeve], Photography By – Trevor Key  \
# 33         Fair (F)               Printed By – Grafiche Boccadoro
#
#                                                 Notes
# 37          Made in Spain\nT.G. Hostench, S.A. (1983)
# 33  Side One\n1 The Rokes Che Colpa Abbiamo Noi\n2...

# %%
#In this code, we are creating a new column that contains the date 
# values from the date_added column without the time information. 
# The date format is yyyy-mm-dd, which consists of 10 characters.

df['Date_Added'] = df['Date_Added'].str[:10]

# %%
df.sample(2)
# Out:
#       Catalog_ID             Artist                Title Label     Format
# 33      NL 33153            Various  I Supergruppi Vol.1   RCA   LP, Comp  \
# 9   CBS 460270 1  Bruce Springsteen       Tunnel Of Love   CBS  LP, Album
#
#     Rating  Released  Release_id    Collection_Folder  Date_Added
# 33       2      1980     5506737    Father Collection  2023-04-24  \
# 9        3      1987     3116927  Original Collection  2023-04-20
#
#         Album_Type                        Style      Genre
# 33      Collection          Pop Rock, Prog Rock  Rock, Pop  \
# 9   Studio Album\n  Soft Rock, Pop Rock, Ballad  Rock, Pop
#
#                                       Recorded  Original_Released
# 33                                         NaN               1980  \
# 9   A&M Studios \nLos Angeles, California, USA               1987
#
#     Artist_City Artist_Country Artist_Region_State Purchased Year_Purchased
# 33          NaN          Italy                 NaN  In-Store           1980  \
# 9   Long Branch         U.S.A.          New Jersey  In-Store           1987
#
#        Shop Shop_City Shop_Region_State Shop_Country  Years_Active Group
# 33  Unknown   Unknown           Unknown        Italy           NaN    No  \
# 9       NaN   Aprilia             Lazio        Italy  1964–present    No
#
#    Group_Members                                      Instrument(s)
# 33           NaN                                                NaN  \
# 9            NaN  Vocals, guitar, Effects [Sound] - Bruce Spring...
#
#                                       Instrument(s)_2 Instrument(s)_3
# 33                                                NaN             NaN  \
# 9   Vocals – Patti Scialfa\nSynthesizer, Piano – R...             NaN
#
#    Instrument(s)_4 Media_Condition Sleeve_Condition
# 33             NaN        Fair (F)         Fair (F)  \
# 9              NaN        Fair (F)         Good (G)
#
#                                             Cover_Art
# 33                    Printed By – Grafiche Boccadoro  \
# 9   Art Direction – Sandra Choron\nPhotography By ...
#
#                                                 Notes
# 33  Side One\n1 The Rokes Che Colpa Abbiamo Noi\n2...
# 9                  Distributed By – CBS Dischi S.p.A.

# %%
df.isnull().sum()
# Out:
# Catalog_ID              0
# Artist                  0
# Title                   0
# Label                   0
# Format                  0
# Rating                  0
# Released                0
# Release_id              0
# Collection_Folder       0
# Date_Added              0
# Album_Type              1
# Style                   0
# Genre                   0
# Recorded                2
# Original_Released       0
# Artist_City             2
# Artist_Country          1
# Artist_Region_State     2
# Purchased               0
# Year_Purchased          0
# Shop                    1
# Shop_City               1
# Shop_Region_State       1
# Shop_Country            0
# Years_Active            1
# Group                   0
# Group_Members          15
# Instrument(s)           1
# Instrument(s)_2         6
# Instrument(s)_3        15
# Instrument(s)_4        27
# Media_Condition         0
# Sleeve_Condition        0
# Cover_Art               0
# Notes                   3
# dtype: int64

# %%
null_rows = df[df['Album_Type'].isnull()]

# %%
null_rows
# Out:
#                          Catalog_ID                    Artist    Title
# 4  10 C 066-060.792, 10C066-060.792  The Alan Parsons Project  Pyramid  \
#
#             Label     Format  Rating  Released  Release_id Collection_Folder
# 4  Arista, Arista  LP, Album       4      1978     3963818  2023 Second Hand  \
#
#    Date_Added Album_Type                                    Style Genre
# 4  2023-04-20        NaN  Pop Rock, Art Rock, Prog Rock, New Wave  Rock  \
#
#                                   Recorded  Original_Released Artist_City
# 4  Abbey Road Studios\nLondon, England, UK               1978      London  \
#
#   Artist_Country Artist_Region_State Purchased Year_Purchased
# 4             UK             England  In-Store           2023  \
#
#                                Shop  Shop_City Shop_Region_State Shop_Country
# 4  Mercado Dominical de Sant Antoni  Barcelona         Catalonia        Spain  \
#
#   Years_Active Group                Group_Members
# 4    1975–1990   Yes  Alan Parsons, Eric Woolfson  \
#
#                                        Instrument(s) Instrument(s)_2
# 4  David Paton – bass, vocals\nStuart Elliott – d...             NaN  \
#
#   Instrument(s)_3 Instrument(s)_4 Media_Condition Sleeve_Condition
# 4             NaN             NaN        Fair (F)         Fair (F)  \
#
#                                   Cover_Art
# 4  Photography By – Hipgnosis (2), Brimson*  \
#
#                                                Notes
# 4  Not-gatefold cover. It has an inner sleeve wit...

# %%
# Replace null value in the column 'Album_Type' with 'Conceptual'
df['Album_Type'].fillna('Conceptual', inplace=True)

# %%
# Check the row index of the "Album" Pyramid so that I can check it has been substitute
row_index = df.loc[df['Title'] == 'Pyramid'].index[0]
print("Row index:", row_index)
# Out:
# Row index: 4

# %%
row_index = 4  # I know that Pyramid is row 4 and I want to check is it correct now.
cell_value = df.loc[row_index, 'Album_Type']
if cell_value == 'Conceptual':
    print(f"The value in row {row_index} has been replaced with 'Conceptual'")
else:
    print(f"The value in row {row_index} has not been replaced with 'Conceptual'")
# Out:
# The value in row 4 has been replaced with 'Conceptual'

# %%
#I also check the null
df.isnull().sum()
# Out:
# Catalog_ID              0
# Artist                  0
# Title                   0
# Label                   0
# Format                  0
# Rating                  0
# Released                0
# Release_id              0
# Collection_Folder       0
# Date_Added              0
# Album_Type              0
# Style                   0
# Genre                   0
# Recorded                2
# Original_Released       0
# Artist_City             2
# Artist_Country          1
# Artist_Region_State     2
# Purchased               0
# Year_Purchased          0
# Shop                    1
# Shop_City               1
# Shop_Region_State       1
# Shop_Country            0
# Years_Active            1
# Group                   0
# Group_Members          15
# Instrument(s)           1
# Instrument(s)_2         6
# Instrument(s)_3        15
# Instrument(s)_4        27
# Media_Condition         0
# Sleeve_Condition        0
# Cover_Art               0
# Notes                   3
# dtype: int64

# %%
null_rows_recorded = df[df['Recorded'].isnull()]

# %%
null_rows_recorded
# Out:
#      Catalog_ID    Artist                         Title            Label
# 31  19439826361  Mina (3)  Cassiopea (Italian Songbook)  PDU, Sony Music  \
# 33     NL 33153   Various           I Supergruppi Vol.1              RCA
#
#                  Format  Rating  Released  Release_id    Collection_Folder
# 31  2xLP, Comp, RM, Blu       3      2020    16276066  Original Collection  \
# 33             LP, Comp       2      1980     5506737    Father Collection
#
#     Date_Added  Album_Type                Style      Genre Recorded
# 31  2023-04-24  Collection       Chanson, Vocal        Pop      NaN  \
# 33  2023-04-24  Collection  Pop Rock, Prog Rock  Rock, Pop      NaN
#
#     Original_Released    Artist_City Artist_Country Artist_Region_State
# 31               2020  Busto Arsizio          Italy           Lombardia  \
# 33               1980            NaN          Italy                 NaN
#
#    Purchased Year_Purchased        Shop  Shop_City Shop_Region_State
# 31  In-Store           2021  100 Discos  Barcelona         Catalonia  \
# 33  In-Store           1980     Unknown    Unknown           Unknown
#
#    Shop_Country     Years_Active Group Group_Members
# 31        Spain  1958 - Presents    No           NaN  \
# 33        Italy              NaN    No           NaN
#
#                                         Instrument(s)
# 31  Bass – Mino Fabiano, Massimo Moriconi, Charl\n...  \
# 33                                                NaN
#
#                                       Instrument(s)_2
# 31  Keyboards – Aldo Banfi, Rocco Tanica, Celso Va...  \
# 33                                                NaN
#
#                                       Instrument(s)_3
# 31  Backing Vocals [Coro] – Massimiliano Pani\nSax...  \
# 33                                                NaN
#
#                                       Instrument(s)_4       Media_Condition
# 31  Backing Vocals – Davide Piazza, Filippo Bernar...  Near Mint (NM or M-)  \
# 33                                                NaN              Fair (F)
#
#         Sleeve_Condition                                          Cover_Art
# 31  Near Mint (NM or M-)  Graphics – Giuseppe Spada\nIllustration – Gian...  \
# 33              Fair (F)                    Printed By – Grafiche Boccadoro
#
#                                                 Notes
# 31  Round sticker on sleeve with text:\nContiene l...
# 33  Side One\n1 The Rokes Che Colpa Abbiamo Noi\n2...

# %%
# Replace null value in the column 'Recorded' with 'Unknown'
df['Recorded'].fillna('Unknown', inplace=True)

# %%
row_indices = [31, 33]  # list of row indices to check
for row_index in row_indices:
    cell_value = df.loc[row_index, 'Recorded']
    if cell_value == 'Unknown':
        print(f"The value in row {row_index} has been replaced with 'Unknown'")
    else:
        print(f"The value in row {row_index} has not been replaced with 'Unknown'")
# Out:
# The value in row 31 has been replaced with 'Unknown'
# The value in row 33 has been replaced with 'Unknown'

# %%
#I also check the null
df.isnull().sum()
# Out:
# Catalog_ID              0
# Artist                  0
# Title                   0
# Label                   0
# Format                  0
# Rating                  0
# Released                0
# Release_id              0
# Collection_Folder       0
# Date_Added              0
# Album_Type              0
# Style                   0
# Genre                   0
# Recorded                0
# Original_Released       0
# Artist_City             2
# Artist_Country          1
# Artist_Region_State     2
# Purchased               0
# Year_Purchased          0
# Shop                    1
# Shop_City               1
# Shop_Region_State       1
# Shop_Country            0
# Years_Active            1
# Group                   0
# Group_Members          15
# Instrument(s)           1
# Instrument(s)_2         6
# Instrument(s)_3        15
# Instrument(s)_4        27
# Media_Condition         0
# Sleeve_Condition        0
# Cover_Art               0
# Notes                   3
# dtype: int64

# %%
null_rows_artist_city = df[df['Artist_City'].isnull()]

# %%
null_rows_artist_city
# Out:
#       Catalog_ID   Artist                Title Label         Format  Rating
# 17  3C 064-94519    Queen                Queen   EMI  LP, Album, RE       4  \
# 33      NL 33153  Various  I Supergruppi Vol.1   RCA       LP, Comp       2
#
#     Released  Release_id    Collection_Folder  Date_Added    Album_Type
# 17      1981     5282336  Original Collection  2023-04-26  Studio Album  \
# 33      1980     5506737    Father Collection  2023-04-24    Collection
#
#                                        Style      Genre
# 17  Hard Rock, Heavy Metal, Progressive Rock       Rock  \
# 33                       Pop Rock, Prog Rock  Rock, Pop
#
#                                     Recorded  Original_Released Artist_City
# 17  De Lane Lea\nTrident\nLondon, England UK               1973         NaN  \
# 33                                   Unknown               1980         NaN
#
#    Artist_Country Artist_Region_State Purchased Year_Purchased     Shop
# 17            NaN                 NaN  In-Store           1987  Unknown  \
# 33          Italy                 NaN  In-Store           1980  Unknown
#
#    Shop_City Shop_Region_State Shop_Country  Years_Active Group
# 17      Rome             Lazio        Italy  1970–present   Yes  \
# 33   Unknown           Unknown        Italy           NaN    No
#
#                                         Group_Members
# 17  Brian May\nFreddy Mercury\nJohn Deacon\nJohn T...  \
# 33                                                NaN
#
#                                         Instrument(s)
# 17  Bass Guitar - John Deacon\nDrums, Percussion, ...  \
# 33                                                NaN
#
#                   Instrument(s)_2
# 17  Backing Vocals - John Anthony  \
# 33                            NaN
#
#                                  Instrument(s)_3
# 17  Production by Roy Thomas Baker, John Anthony  \
# 33                                           NaN
#
#                                       Instrument(s)_4 Media_Condition
# 17  Written by  May, Staffell, Mercury, Taylor\nPr...  Very Good (VG)  \
# 33                                                NaN        Fair (F)
#
#    Sleeve_Condition                                          Cover_Art
# 17         Poor (P)  Cover, Design [Cover] – Brian, Douglas, Freddi...  \
# 33         Fair (F)                    Printed By – Grafiche Boccadoro
#
#                                                 Notes
# 17                                       80's reissue
# 33  Side One\n1 The Rokes Che Colpa Abbiamo Noi\n2...

# %%
# Replace the value null in row 33 with 'Unknown'
row_index = 33
columns_to_update = ['Artist_City', 'Artist_Region_State', 'Artist_Country', 'Years_Active',
                     'Instrument(s)', 'Instrument(s)_2', 'Instrument(s)_3', 'Instrument(s)_4',
                     'Group_Members']
for column in columns_to_update:
    df.loc[row_index, column] = 'Unknown'

# %%
df.loc[33]
# Out:
# Catalog_ID                                                      NL 33153
# Artist                                                           Various
# Title                                                I Supergruppi Vol.1
# Label                                                                RCA
# Format                                                          LP, Comp
# Rating                                                                 2
# Released                                                            1980
# Release_id                                                       5506737
# Collection_Folder                                      Father Collection
# Date_Added                                                    2023-04-24
# Album_Type                                                    Collection
# Style                                                Pop Rock, Prog Rock
# Genre                                                          Rock, Pop
# Recorded                                                         Unknown
# Original_Released                                                   1980
# Artist_City                                                      Unknown
# Artist_Country                                                   Unknown
# Artist_Region_State                                              Unknown
# Purchased                                                       In-Store
# Year_Purchased                                                      1980
# Shop                                                             Unknown
# Shop_City                                                        Unknown
# Shop_Region_State                                                Unknown
# Shop_Country                                                       Italy
# Years_Active                                                     Unknown
# Group                                                                 No
# Group_Members                                                    Unknown
# Instrument(s)                                                    Unknown
# Instrument(s)_2                                                  Unknown
# Instrument(s)_3                                                  Unknown
# Instrument(s)_4                                                  Unknown
# Media_Condition                                                 Fair (F)
# Sleeve_Condition                                                Fair (F)
# Cover_Art                                Printed By – Grafiche Boccadoro
# Notes                  Side One\n1 The Rokes Che Colpa Abbiamo Noi\n2...
# Name: 33, dtype: object

# %%
# Replace the value null in row 33 with 'Unknown'
row_index = 33
columns_to_update = ['Artist_City', 'Artist_Region_State', 'Artist_Country', 'Years_Active',
                     'Instrument(s)', 'Instrument(s)_2', 'Instrument(s)_3', 'Instrument(s)_4',
                     'Group_Members']
for column in columns_to_update:
    df.loc[row_index, column] = 'Unknown'

# %%
df.loc[17]
# Out:
# Catalog_ID                                                  3C 064-94519
# Artist                                                             Queen
# Title                                                              Queen
# Label                                                                EMI
# Format                                                     LP, Album, RE
# Rating                                                                 4
# Released                                                            1981
# Release_id                                                       5282336
# Collection_Folder                                    Original Collection
# Date_Added                                                    2023-04-26
# Album_Type                                                  Studio Album
# Style                           Hard Rock, Heavy Metal, Progressive Rock
# Genre                                                               Rock
# Recorded                        De Lane Lea\nTrident\nLondon, England UK
# Original_Released                                                   1973
# Artist_City                                                          NaN
# Artist_Country                                                       NaN
# Artist_Region_State                                                  NaN
# Purchased                                                       In-Store
# Year_Purchased                                                      1987
# Shop                                                             Unknown
# Shop_City                                                           Rome
# Shop_Region_State                                                  Lazio
# Shop_Country                                                       Italy
# Years_Active                                                1970–present
# Group                                                                Yes
# Group_Members          Brian May\nFreddy Mercury\nJohn Deacon\nJohn T...
# Instrument(s)          Bass Guitar - John Deacon\nDrums, Percussion, ...
# Instrument(s)_2                            Backing Vocals - John Anthony
# Instrument(s)_3             Production by Roy Thomas Baker, John Anthony
# Instrument(s)_4        Written by  May, Staffell, Mercury, Taylor\nPr...
# Media_Condition                                           Very Good (VG)
# Sleeve_Condition                                                Poor (P)
# Cover_Art              Cover, Design [Cover] – Brian, Douglas, Freddi...
# Notes                                                       80's reissue
# Name: 17, dtype: object

# %%
df.loc[17, 'Artist_City'] = 'London'
df.loc[17, 'Artist_Country'] = 'UK'
df.loc[17, 'Artist_Region_State'] = 'England'
df.loc[17, 'Shop'] = 'Unknown'

# %%
#I also check the null
df.isnull().sum()
# Out:
# Catalog_ID              0
# Artist                  0
# Title                   0
# Label                   0
# Format                  0
# Rating                  0
# Released                0
# Release_id              0
# Collection_Folder       0
# Date_Added              0
# Album_Type              0
# Style                   0
# Genre                   0
# Recorded                0
# Original_Released       0
# Artist_City             1
# Artist_Country          0
# Artist_Region_State     0
# Purchased               0
# Year_Purchased          0
# Shop                    1
# Shop_City               1
# Shop_Region_State       1
# Shop_Country            0
# Years_Active            0
# Group                   0
# Group_Members          14
# Instrument(s)           0
# Instrument(s)_2         5
# Instrument(s)_3        14
# Instrument(s)_4        26
# Media_Condition         0
# Sleeve_Condition        0
# Cover_Art               0
# Notes                   3
# dtype: int64

# %%
null_rows_shop = df[df['Shop'].isnull()]

# %%
null_rows_shop
# Out:
#      Catalog_ID             Artist           Title Label     Format  Rating
# 9  CBS 460270 1  Bruce Springsteen  Tunnel Of Love   CBS  LP, Album       3  \
#
#    Released  Release_id    Collection_Folder  Date_Added      Album_Type
# 9      1987     3116927  Original Collection  2023-04-20  Studio Album\n  \
#
#                          Style      Genre
# 9  Soft Rock, Pop Rock, Ballad  Rock, Pop  \
#
#                                      Recorded  Original_Released  Artist_City
# 9  A&M Studios \nLos Angeles, California, USA               1987  Long Branch  \
#
#   Artist_Country Artist_Region_State Purchased Year_Purchased Shop Shop_City
# 9         U.S.A.          New Jersey  In-Store           1987  NaN   Aprilia  \
#
#   Shop_Region_State Shop_Country  Years_Active Group Group_Members
# 9             Lazio        Italy  1964–present    No           NaN  \
#
#                                        Instrument(s)
# 9  Vocals, guitar, Effects [Sound] - Bruce Spring...  \
#
#                                      Instrument(s)_2 Instrument(s)_3
# 9  Vocals – Patti Scialfa\nSynthesizer, Piano – R...             NaN  \
#
#   Instrument(s)_4 Media_Condition Sleeve_Condition
# 9             NaN        Fair (F)         Good (G)  \
#
#                                            Cover_Art
# 9  Art Direction – Sandra Choron\nPhotography By ...  \
#
#                                 Notes
# 9  Distributed By – CBS Dischi S.p.A.

# %%
df.loc[9]
# Out:
# Catalog_ID                                                  CBS 460270 1
# Artist                                                 Bruce Springsteen
# Title                                                     Tunnel Of Love
# Label                                                                CBS
# Format                                                         LP, Album
# Rating                                                                 3
# Released                                                            1987
# Release_id                                                       3116927
# Collection_Folder                                    Original Collection
# Date_Added                                                    2023-04-20
# Album_Type                                                Studio Album\n
# Style                                        Soft Rock, Pop Rock, Ballad
# Genre                                                          Rock, Pop
# Recorded                      A&M Studios \nLos Angeles, California, USA
# Original_Released                                                   1987
# Artist_City                                                  Long Branch
# Artist_Country                                                    U.S.A.
# Artist_Region_State                                           New Jersey
# Purchased                                                       In-Store
# Year_Purchased                                                      1987
# Shop                                                             Unknown
# Shop_City                                                        Aprilia
# Shop_Region_State                                                  Lazio
# Shop_Country                                                       Italy
# Years_Active                                                1964–present
# Group                                                                 No
# Group_Members                                                       None
# Instrument(s)          Vocals, guitar, Effects [Sound] - Bruce Spring...
# Instrument(s)_2        Vocals – Patti Scialfa\nSynthesizer, Piano – R...
# Instrument(s)_3                                                  Unknown
# Instrument(s)_4                                                  Unknown
# Media_Condition                                                 Fair (F)
# Sleeve_Condition                                                Good (G)
# Cover_Art              Art Direction – Sandra Choron\nPhotography By ...
# Notes                                 Distributed By – CBS Dischi S.p.A.
# Name: 9, dtype: object

# %%
# Replace the value null in row 9 with 'Unknown'
row_index = 9
columns_to_update = ['Shop', 'Group_Members','Instrument(s)_3', 'Instrument(s)_4',
                     'Group_Members']
for column in columns_to_update:
    df.loc[row_index, column] = 'Unknown'

# %%
null_counts = df.isnull().sum()
null_counts = null_counts[null_counts != 0]  # Remove columns with no null values
null_counts
# Out:
# Series([], dtype: int64)

# %%
null_rows_Shop_City = df[df['Shop_City'].isnull()]

# %%
null_rows_Shop_City
# Out:
# Empty DataFrame
# Columns: [Catalog_ID, Artist, Title, Label, Format, Rating, Released, Release_id, Collection_Folder, Date_Added, Album_Type, Style, Genre, Recorded, Original_Released, Artist_City, Artist_Country, Artist_Region_State, Purchased, Year_Purchased, Shop, Shop_City, Shop_Region_State, Shop_Country, Years_Active, Group, Group_Members, Instrument(s), Instrument(s)_2, Instrument(s)_3, Instrument(s)_4, Media_Condition, Sleeve_Condition, Cover_Art, Notes]
# Index: []

# %%
# This code selects the rows where Purchased is Online, and then sets the value of the 
# Shop_City and Shop_Region_State columns for those rows to 'Online'
df.loc[df['Purchased'] == 'Online', ['Shop_City', 'Shop_Region_State']] = 'Online'

# %%
df.loc[0]
# Out:
# Catalog_ID                                                        350203
# Artist                                                    Billie Holiday
# Title                                                      Lady In Satin
# Label                                           20th Century Masterworks
# Format                                                  LP, Ltd, RE, Pur
# Rating                                                                 4
# Released                                                            2020
# Release_id                                                      15999105
# Collection_Folder                                    Original Collection
# Date_Added                                                    2023-04-24
# Album_Type                                                    Collection
# Style                                                               Jazz
# Genre                                                               Jazz
# Recorded                                                         Unknown
# Original_Released                                                   1958
# Artist_City                                                 Philadelphia
# Artist_Country                                                       USA
# Artist_Region_State                                         Pennsylvania
# Purchased                                                         Online
# Year_Purchased                                                      2021
# Shop                                                              Amazon
# Shop_City                                                         Online
# Shop_Region_State                                                 Online
# Shop_Country                                                       Spain
# Years_Active                                                   1930–1959
# Group                                                                 No
# Group_Members                                                       None
# Instrument(s)          Vocal - Billie Holiday\nviolin and concertmast...
# Instrument(s)_2        cello - David Soyer, Maurice Brown\nHarp - Jan...
# Instrument(s)_3        Trombone - J.J. Johnson, Urbie Green\nbass tro...
# Instrument(s)_4                                                     None
# Media_Condition                                     Near Mint (NM or M-)
# Sleeve_Condition                                    Near Mint (NM or M-)
# Cover_Art                  Photo by Michael Ochs Archives / Getty Images
# Notes                  Originally released as Lady in Satin (Columbia...
# Name: 0, dtype: object

# %%
# This code selects the rows where Group is No, and then sets the value of the 
# Group_Members columns for those rows to 'None'
df.loc[df['Group'] == 'No', ['Group_Members']] = 'None'

# %%
columns_to_check = ['Instrument(s)', 'Instrument(s)_2', 'Instrument(s)_3', 'Instrument(s)_4']

for col in columns_to_check:
    df[col] = df[col].fillna("None")

# %%
df.loc[10]
# Out:
# Catalog_ID                                                        LPX 20
# Artist                                                        New Trolls
# Title                                                                 UT
# Label                                                              Cetra
# Format                                                    LP, Album, Gat
# Rating                                                                 3
# Released                                                            1972
# Release_id                                                       1464421
# Collection_Folder                                      Father Collection
# Date_Added                                                    2023-04-25
# Album_Type                                                  Studio Album
# Style                            Classic Rock, Prog Rock, Symphonic Rock
# Genre                                                               Rock
# Recorded               Sala di registrazioni Fonit-Cetra\nMilano, Lom...
# Original_Released                                                   1972
# Artist_City                                                       Genova
# Artist_Country                                                     Italy
# Artist_Region_State                                              Liguria
# Purchased                                                       In-Store
# Year_Purchased                                                      1972
# Shop                                                             Unknown
# Shop_City                                                        Unknown
# Shop_Region_State                                                Unknown
# Shop_Country                                                       Italy
# Years_Active                                                1967–present
# Group                                                                Yes
# Group_Members          Nico Di Palo\nVittorio De Scalzi\nMaurizio Sal...
# Instrument(s)          Bass – Frank Laugelli\nDrums, Vocals – Gianni ...
# Instrument(s)_2        Music By – Dini* (tracks: A4 to B3), Rhodes* (...
# Instrument(s)_3                                                     None
# Instrument(s)_4                                                     None
# Media_Condition                                           Good Plus (G+)
# Sleeve_Condition                                    Very Good Plus (VG+)
# Cover_Art                  Design Concept [Su Una Idea Dei] – New Trolls
# Notes                                                               None
# Name: 10, dtype: object

# %%
columns_to_check = ['Notes']

for col in columns_to_check:
    df[col] = df[col].fillna("None")

# %%
null_counts_2 = df.isnull().sum()
null_counts_2 = null_counts_2[null_counts_2 != 0]  # Remove columns with no null values
null_counts_2
# Out:
# Series([], dtype: int64)

# %%
df.to_csv('../Discogs_Exports/WannaCollection_40.csv', index=0)
